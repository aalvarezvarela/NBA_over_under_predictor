# %% [markdown]
# # Classification NBA Model

# %% [markdown]
# ## Configuration

# %%
from pathlib import Path

save_models_path = "/home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/"
Path(save_models_path).mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ## Imports

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from autogluon.tabular import TabularPredictor
from nba_ou.data_preparation.missing_data.handle_missing_data import (
    apply_missing_policy,
)
from sklearn.dummy import DummyClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import (
    accuracy_score,
    balanced_accuracy_score,
    confusion_matrix,
    f1_score,
    make_scorer,
    precision_score,
    recall_score,
)
from sklearn.model_selection import KFold, cross_validate, train_test_split
from xgboost import XGBClassifier

# %% [markdown]
# ## Load Data

# %%
data_path = "/home/adrian_alvarez/Projects/NBA_over_under_predictor/data/train_data/"
name = "all_odds_training_data_until_20260120.csv"

path = data_path + name

df_stats = pd.read_csv(path)

dtype_dict = {col: str for col in df_stats.columns if "ID" in col.upper()}

df_stats = pd.read_csv(
    path,
    dtype=dtype_dict
)
df_stats['GAME_DATE'] = pd.to_datetime(df_stats['GAME_DATE']).dt.strftime('%Y-%m-%d')
# Out:
# /tmp/ipykernel_67625/553953922.py:6: DtypeWarning: Columns (497,498,499,540,541,542,583,584,585,626,627,628,669,670,671,712,713,714,1200,1201,1202,1243,1244,1245,1286,1287,1288,1329,1330,1331,1372,1373,1374,1415,1416,1417) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_stats = pd.read_csv(path)
# /tmp/ipykernel_67625/553953922.py:10: DtypeWarning: Columns (497,498,499,540,541,542,583,584,585,626,627,628,669,670,671,712,713,714,1200,1201,1202,1243,1244,1245,1286,1287,1288,1329,1330,1331,1372,1373,1374,1415,1416,1417) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_stats = pd.read_csv(

# %%
from nba_ou.data_preparation.missing_data.clean_df_for_training import (
    clean_dataframe_for_training
)
# df_to_train = clean_dataframe_for_training(df_stats, nan_threshold=4, drop_all_na_rows=True, verbose=1)
df_to_train = clean_dataframe_for_training(df_stats, nan_threshold=3, drop_all_na_rows=True, verbose=1)
# Out:
# ================================================================================
# STARTING DATAFRAME CLEANING PIPELINE
# ================================================================================
# Starting basic cleaning with 10870 rows
# Basic cleaning complete: 8050 rows remaining
#
# Starting advanced column cleaning with 1805 columns
#
# Advanced column cleaning complete: 1805 → 816 columns (989 removed)
#
#
# Dropping NA rows for SEASON_YEAR 2017...
#    Removed 0 rows with NaN values from 2017 season
#
# Applying missing data policy...
#
# Missing Data Policy Report:
#   Rows dropped: 0 (0.0%)
#   Critical columns requiring data: 5
#   Columns zero-filled: 132
#   Infer pairs applied: 54/228
#   Remaining NaN cells: 14638
#
# Dropping rows that are all NaN...
# ================================================================================
# CLEANING COMPLETE
# Final shape: (7194, 816)
# ================================================================================

# %%
# Count NAs per column
na_counts = df_to_train.isna().sum()

# Get most common SEASON_YEAR for nulls in each column
most_common_season = []
for col in df_to_train.columns:
    if na_counts[col] > 0:
        # Get rows where this column is null
        null_rows = df_stats[df_stats[col].isna()]
        if len(null_rows) > 0 and 'SEASON_YEAR' in df_stats.columns:
            # Find most common SEASON_YEAR for these null rows
            common_season = null_rows['SEASON_YEAR'].mode()
            most_common_season.append(common_season.iloc[0] if len(common_season) > 0 else None)
        else:
            most_common_season.append(None)
    else:
        most_common_season.append(None)

na_counts_df = pd.DataFrame({
    'Column': na_counts.index,
    'NA_Count': na_counts.values,
    'NA_Percentage': (na_counts.values / len(df_to_train) * 100).round(2),
    'Most_Common_Season_Year': most_common_season
}).sort_values('NA_Count', ascending=False)

# Show only columns with NAs
na_counts_df[na_counts_df['NA_Count'] > 0]
# Out:
# Empty DataFrame
# Columns: [Column, NA_Count, NA_Percentage, Most_Common_Season_Year]
# Index: []

# %%
df_to_train = df_to_train[df_to_train['TOTAL_POINTS'] != df_to_train['TOTAL_OVER_UNDER_LINE']]

# %%
df_to_train['OVER_UNDER'] = np.where(df_to_train['TOTAL_POINTS'] >= df_to_train['TOTAL_OVER_UNDER_LINE'], 1, 0) # 1 if over, 0 if under

# %%
#count 1 and 0 in OVER_UNDER
df_to_train['OVER_UNDER'].value_counts()
# Out:
# OVER_UNDER
# 0    3695
# 1    3413
# Name: count, dtype: int64

# %%
# df_to_train= df_to_train[df_to_train['SEASON_YEAR'] != 2018]

# %% [markdown]
# ## Train / Test

# %%
X = df_to_train.drop(['TOTAL_POINTS', 'OVER_UNDER', 'SEASON_YEAR'], axis=1, errors='ignore')
y = df_to_train['OVER_UNDER']

# %%
# Train / Test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=16)

# %%
df_to_train['IS_TRAINING_DATA'] = False

# Mark True for the rows in the training set
df_to_train.loc[X_train.index, 'IS_TRAINING_DATA'] = True
# output_name = f"{data_path}/training_data_with_missing_data_handled_from_2004-10-01_to_2026-01-10_classifier.csv"
# df_to_train.to_csv(output_name, index=False)

# %%
print(f"Training set size: {X_train.shape[0]}")
print(f"Test set size: {X_test.shape[0]}")
# Check number of coulmns
print(f"Number of columns in training set: {X_train.shape[1]}")
print(f"Number of columns in test set: {X_test.shape[1]}")
# Out:
# Training set size: 5331
# Test set size: 1777
# Number of columns in training set: 814
# Number of columns in test set: 814

# %% [markdown]
# ## Cross-validation

# %%
# Declare KFold
kf = KFold(n_splits=5, shuffle=True, random_state=16)

# %%
# Declare scores to be used
scoring = {
    'Acc': make_scorer(accuracy_score),
    'Prec': make_scorer(precision_score),
    'Rec': make_scorer(recall_score),
    'Bacc': make_scorer(balanced_accuracy_score),
}

# %%
def print_classification_metrics(cv_results, scoring):
    """
    Prints the mean cross-validation scores for each metric on train and validation folds.
    """
    for sc in scoring.keys():
        print(f"Train {sc}:", cv_results[f'train_{sc}'].mean().round(5))
        print(f"Validation {sc}:", cv_results[f'test_{sc}'].mean().round(5))
        print()

# %% [markdown]
# ## Baseline

# %%
dummy_clf = DummyClassifier(strategy='most_frequent')
cv_results = cross_validate(
    dummy_clf, 
    X_train, 
    y_train, 
    cv=kf, 
    scoring=scoring, 
    return_train_score=True
)
dummy_clf.fit(X_train, y_train)
print("=== Dummy (Most Frequent) Classifier ===")
print_classification_metrics(cv_results, scoring)
# Out:
# === Dummy (Most Frequent) Classifier ===
# Train Acc: 0.52129
# Validation Acc: 0.52129
#
# Train Prec: 0.0
# Validation Prec: 0.0
#
# Train Rec: 0.0
# Validation Rec: 0.0
#
# Train Bacc: 0.5
# Validation Bacc: 0.5
# /home/adrian_alvarez/Projects/NBA_over_under_predictor/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/adrian_alvarez/Projects/NBA_over_under_predictor/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/adrian_alvarez/Projects/NBA_over_under_predictor/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/adrian_alvarez/Projects/NBA_over_under_predictor/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/adrian_alvarez/Projects/NBA_over_under_predictor/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/adrian_alvarez/Projects/NBA_over_under_predictor/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/adrian_alvarez/Projects/NBA_over_under_predictor/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/adrian_alvarez/Projects/NBA_over_under_predictor/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/adrian_alvarez/Projects/NBA_over_under_predictor/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/adrian_alvarez/Projects/NBA_over_under_predictor/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# ## Logistic Regression

# %%
lr = LogisticRegression(max_iter=1000)
cv_results = cross_validate(
    lr, 
    X_train, 
    y_train, 
    cv=kf, 
    scoring=scoring, 
    return_train_score=True,
    n_jobs=-1
)
lr.fit(X_train, y_train)
# Out:
# /home/adrian_alvarez/Projects/NBA_over_under_predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/adrian_alvarez/Projects/NBA_over_under_predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/adrian_alvarez/Projects/NBA_over_under_predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/adrian_alvarez/Projects/NBA_over_under_predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/adrian_alvarez/Projects/NBA_over_under_predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/adrian_alvarez/Projects/NBA_over_under_predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(max_iter=1000)

# %%
print("=== Logistic Regression ===")
print_classification_metrics(cv_results, scoring)
# Out:
# === Logistic Regression ===
# Train Acc: 0.65063
# Validation Acc: 0.53236
#
# Train Prec: 0.64387
# Validation Prec: 0.51212
#
# Train Rec: 0.60438
# Validation Rec: 0.49254
#
# Train Bacc: 0.64871
# Validation Bacc: 0.53074

# %%
xgb_clf = XGBClassifier(
    max_depth=4,
    learning_rate=0.035,
    n_estimators=300,
    subsample=0.6,
    colsample_bytree=0.8,
    n_jobs=-1,
    random_state=16,
    reg_lambda=1.0,
)

cv_results = cross_validate(
    xgb_clf, 
    X_train, 
    y_train, 
    cv=kf, 
    scoring=scoring, 
    return_train_score=True,
    n_jobs=-1
)

xgb_clf.fit(X_train, y_train)

print("=== XGBClassifier ===")
print_classification_metrics(cv_results, scoring)
# Out:
# === XGBClassifier ===
# Train Acc: 0.96619
# Validation Acc: 0.51847
#
# Train Prec: 0.97498
# Validation Prec: 0.49676
#
# Train Rec: 0.95385
# Validation Rec: 0.43028
#
# Train Bacc: 0.96568
# Validation Bacc: 0.51497

# %%
# Calcualte it in test set
y_pred = xgb_clf.predict(X_test)

#Predict test set with XGBClassifier
y_pred = xgb_clf.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
balan_acc = balanced_accuracy_score(y_test, y_pred)
print("=== XGBClassifier Test Set Performance ===")
print(f"Accuracy: {accuracy:.5f}")
print(f"Precision: {precision:.5f}")    
print(f"Recall: {recall:.5f}")
print(f"F1 Score: {f1:.5f}")
print(f"Balanced Accuracy: {balan_acc:.5f}")

#groupby season_year and calculate accuracy per season
df_test = X_test.copy()
df_test['TRUE_LABEL'] = y_test
df_test['PRED_LABEL'] = y_pred
df_test['CORRECT_PREDICTION'] = np.where(df_test['TRUE_LABEL'] == df_test['PRED_LABEL'], 1, 0)
#merge 'SEASON_YEAR' from df_to_train
df_test = df_test.merge(df_to_train[['SEASON_YEAR']], left_index=True, right_index=True, how='left')
season_accuracy = df_test.groupby('SEASON_YEAR')['CORRECT_PREDICTION'].mean().reset_index()
season_accuracy.rename(columns={'CORRECT_PREDICTION': 'ACCURACY'}, inplace=True)
print("=== Test Set Accuracy by Season ===")
print(season_accuracy)
# Out:
# === XGBClassifier Test Set Performance ===
# Accuracy: 0.50985
# Precision: 0.49356
# Recall: 0.44483
# F1 Score: 0.46793
# Balanced Accuracy: 0.50790
# === Test Set Accuracy by Season ===
#    SEASON_YEAR  ACCURACY
# 0         2019  0.491667
# 1         2020  0.449275
# 2         2021  0.590476
# 3         2022  0.507194
# 4         2023  0.493197
# 5         2024  0.541547
# 6         2025  0.427586

# %% [markdown]
# ## AutoGluon (Hyperparameter Tuning)

# %%
predictor = TabularPredictor(
    label="target",
    problem_type="binary",
    eval_metric="balanced_accuracy",
    path=save_models_path,
).fit(
    train_data=X_train.assign(target=y_train),
    time_limit=3*3600,  # 3 hours
    presets="good_quality",
    hyperparameter_tune_kwargs="auto",
    num_cpus=12,
    # hyperparameters={
    #     "XGB": {},  # only XGBoost models
    # },
)
# Out:
# 2026-02-08 21:34:06,017	INFO timeout.py:54 -- Reached timeout of 480.8754911899567 seconds. Stopping all trials.
# 2026-02-08 21:34:06,029	INFO tune.py:1009 -- Wrote the latest version of all result files and experiment state to '/home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetTorch_BAG_L2' in 0.0092s.
# 2026-02-08 21:34:06,032	WARNING experiment_analysis.py:180 -- Failed to fetch metrics for 5 trial(s):
# - 1271de59: FileNotFoundError('Could not fetch metrics for 1271de59: both result.json and progress.csv were not found at /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetTorch_BAG_L2/1271de59')
# - 8964517e: FileNotFoundError('Could not fetch metrics for 8964517e: both result.json and progress.csv were not found at /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetTorch_BAG_L2/8964517e')
# - 634e5bce: FileNotFoundError('Could not fetch metrics for 634e5bce: both result.json and progress.csv were not found at /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetTorch_BAG_L2/634e5bce')
# - 8cb151fd: FileNotFoundError('Could not fetch metrics for 8cb151fd: both result.json and progress.csv were not found at /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetTorch_BAG_L2/8cb151fd')
# - 11950ac2: FileNotFoundError('Could not fetch metrics for 11950ac2: both result.json and progress.csv were not found at /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetTorch_BAG_L2/11950ac2')
# Fitted model: NeuralNetTorch_BAG_L2/1271de59 ...
# 	0.6014	 = Validation score   (balanced_accuracy)
# 	107.53s	 = Training   runtime
# 	1.11s	 = Validation runtime
# Fitted model: NeuralNetTorch_BAG_L2/8964517e ...
# 	0.5897	 = Validation score   (balanced_accuracy)
# 	297.24s	 = Training   runtime
# 	1.41s	 = Validation runtime
# Fitted model: NeuralNetTorch_BAG_L2/634e5bce ...
# 	0.5484	 = Validation score   (balanced_accuracy)
# 	58.59s	 = Training   runtime
# 	1.16s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ... Training model for up to 480.88s of the 3179.35s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=3.51%)
# 	0.5466	 = Validation score   (balanced_accuracy)
# 	247.15s	 = Training   runtime
# 	0.27s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 587.74s of the 2929.52s of remaining time.
# 	Fitting 1 model on all data | Fitting with cpus=12, gpus=0, mem=0.0/22.5 GB
# 	Ensemble Weights: {'CatBoost_BAG_L2/T1': 0.231, 'NeuralNetTorch_BAG_L2/1271de59': 0.231, 'XGBoost_BAG_L1/T1': 0.077, 'NeuralNetTorch_BAG_L1/d4a5e44b': 0.077, 'LightGBMXT_BAG_L2/T5': 0.077, 'LightGBMXT_BAG_L2/T6': 0.077, 'CatBoost_BAG_L2/T3': 0.077, 'NeuralNetFastAI_BAG_L2/093d235b': 0.077, 'NeuralNetFastAI_BAG_L2/8698089d': 0.077}
# 	0.6035	 = Validation score   (balanced_accuracy)
# 	0.22s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 5942.86s ... Best model: WeightedEnsemble_L3 | Estimated inference throughput: 89.3 rows/s (710 batch size)
# Automatically performing refit_full as a post-fit operation (due to `.fit(..., refit_full=True)`
# Refitting models via `predictor.refit_full` using all of the data (combined train and validation)...
# 	Models trained in this way will have the suffix "_FULL" and have NaN validation score.
# 	This process is not bound by time_limit, but should take less time than the original `predictor.fit` call.
# 	To learn more, refer to the `.refit_full` method docstring which explains how "_FULL" models differ from normal models.
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_BAG_L1/T1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=12, gpus=0, mem=0.3/23.0 GB
# 	2.37s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_BAG_L1/T2_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=12, gpus=0, mem=0.4/23.0 GB
# 	2.75s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_BAG_L1/T3_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=12, gpus=0, mem=0.3/22.8 GB
# 	4.0s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_BAG_L1/T4_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=12, gpus=0, mem=0.4/22.9 GB
# 	5.05s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_BAG_L1/T5_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=12, gpus=0, mem=0.3/22.9 GB
# 	2.22s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_BAG_L1/T6_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=12, gpus=0, mem=0.5/22.9 GB
# 	4.56s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_BAG_L1/T7_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=12, gpus=0, mem=0.4/22.8 GB
# 	3.55s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_BAG_L1/T8_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=12, gpus=0, mem=0.3/22.8 GB
# 	12.02s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_BAG_L1/T1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=12, gpus=0, mem=0.3/22.8 GB
# 	2.64s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_BAG_L1/T2_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=12, gpus=0, mem=0.4/22.8 GB
# 	6.87s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_BAG_L1/T3_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=12, gpus=0, mem=0.3/22.9 GB
# 	4.02s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_BAG_L1/T4_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=12, gpus=0, mem=0.4/22.8 GB
# 	5.66s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_BAG_L1/T5_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=12, gpus=0, mem=0.3/22.8 GB
# 	4.07s	 = Training   runtime
# Fitting model: RandomForestGini_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	6.64s	 = Training   runtime
# 	0.68s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	8.18s	 = Training   runtime
# 	0.69s	 = Validation runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_BAG_L1/T1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=12, gpus=0, mem=1.1/22.8 GB
# 	1.94s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_BAG_L1/T2_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=12, gpus=0
# 	2.46s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_BAG_L1/T3_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=12, gpus=0, mem=1.6/22.8 GB
# 	13.5s	 = Training   runtime
# Fitting model: ExtraTreesGini_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	1.11s	 = Training   runtime
# 	0.67s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	1.02s	 = Training   runtime
# 	0.66s	 = Validation runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_BAG_L1/7864385d_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.3/22.8 GB
# Metric balanced_accuracy is not supported by this model - using log_loss instead
# 	Stopping at the best epoch learned earlier - 0.
# 	0.61s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_BAG_L1/8d559b59_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.3/22.7 GB
# Metric balanced_accuracy is not supported by this model - using log_loss instead
# 	Stopping at the best epoch learned earlier - 4.
# 	1.62s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_BAG_L1/45914bf2_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.3/22.7 GB
# Metric balanced_accuracy is not supported by this model - using log_loss instead
# 	Stopping at the best epoch learned earlier - 0.
# 	0.74s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_BAG_L1/b2b01ccf_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.3/22.6 GB
# Metric balanced_accuracy is not supported by this model - using log_loss instead
# 	Stopping at the best epoch learned earlier - 6.
# 	0.92s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_BAG_L1/307c0815_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.3/22.6 GB
# Metric balanced_accuracy is not supported by this model - using log_loss instead
# 	Stopping at the best epoch learned earlier - 6.
# 	1.06s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_BAG_L1/239eda2d_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.3/22.5 GB
# Metric balanced_accuracy is not supported by this model - using log_loss instead
# 	Stopping at the best epoch learned earlier - 1.
# 	2.59s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_BAG_L1/2a9f22d6_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.3/22.6 GB
# Metric balanced_accuracy is not supported by this model - using log_loss instead
# 	Stopping at the best epoch learned earlier - 3.
# 	3.11s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_BAG_L1/48db6f1f_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.3/22.6 GB
# Metric balanced_accuracy is not supported by this model - using log_loss instead
# 	Stopping at the best epoch learned earlier - 5.
# 	2.9s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_BAG_L1/9dabaff2_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.3/22.5 GB
# Metric balanced_accuracy is not supported by this model - using log_loss instead
# 	Stopping at the best epoch learned earlier - 0.
# 	0.78s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_BAG_L1/666b86c6_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.3/22.5 GB
# Metric balanced_accuracy is not supported by this model - using log_loss instead
# 	Stopping at the best epoch learned earlier - 1.
# 	1.67s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_BAG_L1/22d73b5f_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.3/22.4 GB
# Metric balanced_accuracy is not supported by this model - using log_loss instead
# 	Stopping at the best epoch learned earlier - 0.
# 	0.47s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_BAG_L1/be8c5f41_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.3/22.4 GB
# Metric balanced_accuracy is not supported by this model - using log_loss instead
# 	Stopping at the best epoch learned earlier - 2.
# 	1.49s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_BAG_L1/f29e63b3_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.3/22.4 GB
# Metric balanced_accuracy is not supported by this model - using log_loss instead
# 	Stopping at the best epoch learned earlier - 0.
# 	0.56s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_BAG_L1/1f05f137_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.3/22.5 GB
# Metric balanced_accuracy is not supported by this model - using log_loss instead
# 	Stopping at the best epoch learned earlier - 7.
# 	4.76s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_BAG_L1/bbf5f6a0_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.3/22.4 GB
# Metric balanced_accuracy is not supported by this model - using log_loss instead
# 	Stopping at the best epoch learned earlier - 0.
# 	1.45s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_BAG_L1/T1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=12, gpus=0
# 	3.87s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_BAG_L1/T2_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=12, gpus=0
# 	7.66s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_BAG_L1/T3_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=12, gpus=0, mem=1.1/22.5 GB
# 	18.75s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_BAG_L1/T4_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=12, gpus=0
# 	3.12s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_BAG_L1/a705a1c5_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.1/22.5 GB
# 	3.75s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_BAG_L1/9017436a_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.1/22.5 GB
# 	16.23s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_BAG_L1/d4a5e44b_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.1/22.5 GB
# 	5.02s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_BAG_L1/0b6ed75f_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.1/22.5 GB
# 	4.87s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_BAG_L1/e579f4c4_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.1/22.5 GB
# 	12.01s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_BAG_L1/6fbe0414_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.1/22.5 GB
# 	6.44s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBMLarge_BAG_L1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=12, gpus=0, mem=0.6/22.4 GB
# 	16.85s	 = Training   runtime
# Fitting model: WeightedEnsemble_L2_FULL | Skipping fit via cloning parent ...
# 	Ensemble Weights: {'CatBoost_BAG_L1/T1': 0.222, 'CatBoost_BAG_L1/T3': 0.167, 'LightGBMXT_BAG_L1/T5': 0.111, 'NeuralNetTorch_BAG_L1/d4a5e44b': 0.111, 'NeuralNetTorch_BAG_L1/0b6ed75f': 0.111, 'RandomForestGini_BAG_L1': 0.056, 'CatBoost_BAG_L1/T2': 0.056, 'ExtraTreesGini_BAG_L1': 0.056, 'XGBoost_BAG_L1/T1': 0.056, 'NeuralNetTorch_BAG_L1/a705a1c5': 0.056}
# 	0.15s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_BAG_L2/T1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=12, gpus=0, mem=0.3/22.3 GB
# 	2.45s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_BAG_L2/T2_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=12, gpus=0, mem=0.5/22.3 GB
# 	21.2s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_BAG_L2/T3_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=12, gpus=0, mem=0.3/22.3 GB
# 	25.71s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_BAG_L2/T4_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=12, gpus=0, mem=0.4/22.3 GB
# 	6.55s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_BAG_L2/T5_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=12, gpus=0, mem=0.3/22.3 GB
# 	6.16s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_BAG_L2/T6_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=12, gpus=0, mem=0.5/22.2 GB
# 	30.58s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_BAG_L2/T1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=12, gpus=0, mem=0.3/22.3 GB
# 	3.92s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_BAG_L2/T2_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=12, gpus=0, mem=0.5/22.3 GB
# 	7.35s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_BAG_L2/T3_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=12, gpus=0, mem=0.3/22.3 GB
# 	34.22s	 = Training   runtime
# Fitting model: RandomForestGini_BAG_L2_FULL | Skipping fit via cloning parent ...
# 	7.45s	 = Training   runtime
# 	0.89s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L2_FULL | Skipping fit via cloning parent ...
# 	9.46s	 = Training   runtime
# 	0.89s	 = Validation runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_BAG_L2/T1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=12, gpus=0, mem=1.1/22.3 GB
# 	2.23s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_BAG_L2/T2_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=12, gpus=0
# 	1.05s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_BAG_L2/T3_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=12, gpus=0, mem=1.7/22.2 GB
# 	4.84s	 = Training   runtime
# Fitting model: ExtraTreesGini_BAG_L2_FULL | Skipping fit via cloning parent ...
# 	1.31s	 = Training   runtime
# 	0.87s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L2_FULL | Skipping fit via cloning parent ...
# 	1.13s	 = Training   runtime
# 	0.88s	 = Validation runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_BAG_L2/fbf43ee6_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.3/22.2 GB
# Metric balanced_accuracy is not supported by this model - using log_loss instead
# 	Stopping at the best epoch learned earlier - 0.
# 	0.72s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_BAG_L2/33443946_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.3/22.2 GB
# Metric balanced_accuracy is not supported by this model - using log_loss instead
# 	Stopping at the best epoch learned earlier - 1.
# 	0.73s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_BAG_L2/a34016b0_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.3/22.2 GB
# Metric balanced_accuracy is not supported by this model - using log_loss instead
# 	Stopping at the best epoch learned earlier - 2.
# 	4.1s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_BAG_L2/25014763_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.3/22.2 GB
# Metric balanced_accuracy is not supported by this model - using log_loss instead
# 	Stopping at the best epoch learned earlier - 2.
# 	1.36s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_BAG_L2/243e3879_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.3/22.2 GB
# Metric balanced_accuracy is not supported by this model - using log_loss instead
# 	Stopping at the best epoch learned earlier - 5.
# 	2.55s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_BAG_L2/58e66ad2_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.3/22.2 GB
# Metric balanced_accuracy is not supported by this model - using log_loss instead
# 	Stopping at the best epoch learned earlier - 1.
# 	0.97s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_BAG_L2/aeaeb1d2_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.3/22.1 GB
# Metric balanced_accuracy is not supported by this model - using log_loss instead
# 	Stopping at the best epoch learned earlier - 3.
# 	1.36s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_BAG_L2/093d235b_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.3/22.2 GB
# Metric balanced_accuracy is not supported by this model - using log_loss instead
# 	Stopping at the best epoch learned earlier - 2.
# 	0.67s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_BAG_L2/a11e2489_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.3/22.1 GB
# Metric balanced_accuracy is not supported by this model - using log_loss instead
# 	Stopping at the best epoch learned earlier - 1.
# 	0.89s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_BAG_L2/8698089d_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.3/22.2 GB
# Metric balanced_accuracy is not supported by this model - using log_loss instead
# 	Stopping at the best epoch learned earlier - 6.
# 	0.8s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_BAG_L2/40b6d093_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.3/22.2 GB
# Metric balanced_accuracy is not supported by this model - using log_loss instead
# 	Stopping at the best epoch learned earlier - 18.
# 	5.66s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_BAG_L2/f009b26f_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.3/22.2 GB
# Metric balanced_accuracy is not supported by this model - using log_loss instead
# 	Stopping at the best epoch learned earlier - 0.
# 	0.7s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_BAG_L2/a2584c28_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.3/22.1 GB
# Metric balanced_accuracy is not supported by this model - using log_loss instead
# 	Stopping at the best epoch learned earlier - 0.
# 	0.57s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_BAG_L2/ab746a4b_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.3/22.1 GB
# Metric balanced_accuracy is not supported by this model - using log_loss instead
# 	Stopping at the best epoch learned earlier - 0.
# 	0.73s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_BAG_L2/160ab05d_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.3/22.2 GB
# Metric balanced_accuracy is not supported by this model - using log_loss instead
# 	Stopping at the best epoch learned earlier - 3.
# 	2.48s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_BAG_L2/302e030a_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.3/22.2 GB
# Metric balanced_accuracy is not supported by this model - using log_loss instead
# 	Stopping at the best epoch learned earlier - 0.
# 	0.68s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_BAG_L2/T1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=12, gpus=0
# 	12.46s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_BAG_L2/T2_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=12, gpus=0
# 	18.88s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_BAG_L2/T3_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=12, gpus=0, mem=1.2/22.2 GB
# 	19.87s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_BAG_L2/1271de59_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.1/22.2 GB
# 	16.06s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_BAG_L2/8964517e_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.1/22.3 GB
# 	21.92s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_BAG_L2/634e5bce_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.1/22.3 GB
# 	2.68s	 = Training   runtime
# Fitting 1 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBMLarge_BAG_L2_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=12, gpus=0, mem=0.6/22.2 GB
# 	14.0s	 = Training   runtime
# Fitting model: WeightedEnsemble_L3_FULL | Skipping fit via cloning parent ...
# 	Ensemble Weights: {'CatBoost_BAG_L2/T1': 0.231, 'NeuralNetTorch_BAG_L2/1271de59': 0.231, 'XGBoost_BAG_L1/T1': 0.077, 'NeuralNetTorch_BAG_L1/d4a5e44b': 0.077, 'LightGBMXT_BAG_L2/T5': 0.077, 'LightGBMXT_BAG_L2/T6': 0.077, 'CatBoost_BAG_L2/T3': 0.077, 'NeuralNetFastAI_BAG_L2/093d235b': 0.077, 'NeuralNetFastAI_BAG_L2/8698089d': 0.077}
# 	0.22s	 = Training   runtime
# Updated best model to "WeightedEnsemble_L3_FULL" (Previously "WeightedEnsemble_L3"). AutoGluon will default to using "WeightedEnsemble_L3_FULL" for predict() and predict_proba().
# Refit complete, total runtime = 490.96s ... Best model: "WeightedEnsemble_L3_FULL"
# Enabling decision threshold calibration (calibrate_decision_threshold='auto', metric is valid, problem_type is 'binary')
# Calibrating decision threshold to optimize metric balanced_accuracy | Checking 51 thresholds...
# Calibrating decision threshold via fine-grained search | Checking 38 thresholds...
# 	Base Threshold: 0.500	| val: 0.6035
# 	Best Threshold: 0.501	| val: 0.6037
# Updating predictor.decision_threshold from 0.5 -> 0.501
# 	This will impact how prediction probabilities are converted to predictions in binary classification.
# 	Prediction probabilities of the positive class >0.501 will be predicted as the positive class (1). This can significantly impact metric scores.
# 	You can update this value via `predictor.set_decision_threshold`.
# 	You can calculate an optimal decision threshold on the validation data via `predictor.calibrate_decision_threshold()`.
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("/home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1")

# %%
lb = predictor.leaderboard(silent=True)
lb
# Out:
#                               model  score_val        eval_metric  \
# 0               WeightedEnsemble_L3   0.603549  balanced_accuracy
# 1    NeuralNetTorch_BAG_L2/1271de59   0.601382  balanced_accuracy
# 2    NeuralNetTorch_BAG_L2/8964517e   0.589686  balanced_accuracy
# 3              LightGBMXT_BAG_L2/T5   0.572185  balanced_accuracy
# 4                LightGBM_BAG_L2/T2   0.565058  balanced_accuracy
# ..                              ...        ...                ...
# 169         CatBoost_BAG_L2/T2_FULL        NaN  balanced_accuracy
# 170         CatBoost_BAG_L2/T1_FULL        NaN  balanced_accuracy
# 171         CatBoost_BAG_L1/T3_FULL        NaN  balanced_accuracy
# 172         CatBoost_BAG_L1/T2_FULL        NaN  balanced_accuracy
# 173         CatBoost_BAG_L1/T1_FULL        NaN  balanced_accuracy
#
#      pred_time_val     fit_time  pred_time_val_marginal  fit_time_marginal  \
# 0        10.317663  1671.205706                0.000692           0.223487
# 1         8.013409  1123.554455                1.110602         107.525533
# 2         8.311312  1313.265086                1.408505         297.236163
# 3         7.344771  1076.216113                0.441964          60.187191
# 4         7.104512  1174.885820                0.201705         158.856898
# ..             ...          ...                     ...                ...
# 169            NaN    78.609262                     NaN           1.053865
# 170            NaN    79.782542                     NaN           2.227145
# 171            NaN    13.497491                     NaN          13.497491
# 172            NaN     2.455070                     NaN           2.455070
# 173            NaN     1.940989                     NaN           1.940989
#
#      stack_level  can_infer  fit_order
# 0              3      False         87
# 1              2      False         83
# 2              2      False         84
# 3              2      False         52
# 4              2      False         55
# ..           ...        ...        ...
# 169            2       True        147
# 170            2       True        146
# 171            1       True        105
# 172            1       True        104
# 173            1       True        103
#
# [174 rows x 10 columns]

# %%
# Keep only the best model (+ its dependencies), delete the rest from disk
predictor.delete_models(models_to_keep="best", delete_from_disk=True)

# (Optional) shrink further by removing auxiliary artifacts not needed for prediction
predictor.save_space(remove_data=True)

# Save back to disk (same folder); after this, the directory is much smaller
predictor.save()
# Out:
# Deleting model LightGBMXT_BAG_L1/T1. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/LightGBMXT_BAG_L1/T1 will be removed.
# Deleting model LightGBMXT_BAG_L1/T2. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/LightGBMXT_BAG_L1/T2 will be removed.
# Deleting model LightGBMXT_BAG_L1/T3. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/LightGBMXT_BAG_L1/T3 will be removed.
# Deleting model LightGBMXT_BAG_L1/T4. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/LightGBMXT_BAG_L1/T4 will be removed.
# Deleting model LightGBMXT_BAG_L1/T5. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/LightGBMXT_BAG_L1/T5 will be removed.
# Deleting model LightGBMXT_BAG_L1/T6. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/LightGBMXT_BAG_L1/T6 will be removed.
# Deleting model LightGBMXT_BAG_L1/T7. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/LightGBMXT_BAG_L1/T7 will be removed.
# Deleting model LightGBMXT_BAG_L1/T8. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/LightGBMXT_BAG_L1/T8 will be removed.
# Deleting model LightGBM_BAG_L1/T1. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/LightGBM_BAG_L1/T1 will be removed.
# Deleting model LightGBM_BAG_L1/T2. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/LightGBM_BAG_L1/T2 will be removed.
# Deleting model LightGBM_BAG_L1/T3. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/LightGBM_BAG_L1/T3 will be removed.
# Deleting model LightGBM_BAG_L1/T4. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/LightGBM_BAG_L1/T4 will be removed.
# Deleting model LightGBM_BAG_L1/T5. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/LightGBM_BAG_L1/T5 will be removed.
# Deleting model RandomForestGini_BAG_L1. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/RandomForestGini_BAG_L1 will be removed.
# Deleting model RandomForestEntr_BAG_L1. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/RandomForestEntr_BAG_L1 will be removed.
# Deleting model CatBoost_BAG_L1/T1. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/CatBoost_BAG_L1/T1 will be removed.
# Deleting model CatBoost_BAG_L1/T2. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/CatBoost_BAG_L1/T2 will be removed.
# Deleting model CatBoost_BAG_L1/T3. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/CatBoost_BAG_L1/T3 will be removed.
# Deleting model ExtraTreesGini_BAG_L1. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/ExtraTreesGini_BAG_L1 will be removed.
# Deleting model ExtraTreesEntr_BAG_L1. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/ExtraTreesEntr_BAG_L1 will be removed.
# Deleting model NeuralNetFastAI_BAG_L1/7864385d. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L1/7864385d will be removed.
# Deleting model NeuralNetFastAI_BAG_L1/8d559b59. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L1/8d559b59 will be removed.
# Deleting model NeuralNetFastAI_BAG_L1/45914bf2. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L1/45914bf2 will be removed.
# Deleting model NeuralNetFastAI_BAG_L1/b2b01ccf. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L1/b2b01ccf will be removed.
# Deleting model NeuralNetFastAI_BAG_L1/307c0815. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L1/307c0815 will be removed.
# Deleting model NeuralNetFastAI_BAG_L1/239eda2d. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L1/239eda2d will be removed.
# Deleting model NeuralNetFastAI_BAG_L1/2a9f22d6. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L1/2a9f22d6 will be removed.
# Deleting model NeuralNetFastAI_BAG_L1/48db6f1f. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L1/48db6f1f will be removed.
# Deleting model NeuralNetFastAI_BAG_L1/9dabaff2. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L1/9dabaff2 will be removed.
# Deleting model NeuralNetFastAI_BAG_L1/666b86c6. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L1/666b86c6 will be removed.
# Deleting model NeuralNetFastAI_BAG_L1/22d73b5f. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L1/22d73b5f will be removed.
# Deleting model NeuralNetFastAI_BAG_L1/be8c5f41. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L1/be8c5f41 will be removed.
# Deleting model NeuralNetFastAI_BAG_L1/f29e63b3. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L1/f29e63b3 will be removed.
# Deleting model NeuralNetFastAI_BAG_L1/1f05f137. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L1/1f05f137 will be removed.
# Deleting model NeuralNetFastAI_BAG_L1/bbf5f6a0. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L1/bbf5f6a0 will be removed.
# Deleting model XGBoost_BAG_L1/T1. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/XGBoost_BAG_L1/T1 will be removed.
# Deleting model XGBoost_BAG_L1/T2. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/XGBoost_BAG_L1/T2 will be removed.
# Deleting model XGBoost_BAG_L1/T3. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/XGBoost_BAG_L1/T3 will be removed.
# Deleting model XGBoost_BAG_L1/T4. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/XGBoost_BAG_L1/T4 will be removed.
# Deleting model NeuralNetTorch_BAG_L1/a705a1c5. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetTorch_BAG_L1/a705a1c5 will be removed.
# Deleting model NeuralNetTorch_BAG_L1/9017436a. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetTorch_BAG_L1/9017436a will be removed.
# Deleting model NeuralNetTorch_BAG_L1/d4a5e44b. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetTorch_BAG_L1/d4a5e44b will be removed.
# Deleting model NeuralNetTorch_BAG_L1/0b6ed75f. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetTorch_BAG_L1/0b6ed75f will be removed.
# Deleting model NeuralNetTorch_BAG_L1/e579f4c4. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetTorch_BAG_L1/e579f4c4 will be removed.
# Deleting model NeuralNetTorch_BAG_L1/6fbe0414. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetTorch_BAG_L1/6fbe0414 will be removed.
# Deleting model LightGBMLarge_BAG_L1. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/LightGBMLarge_BAG_L1 will be removed.
# Deleting model WeightedEnsemble_L2. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/WeightedEnsemble_L2 will be removed.
# Deleting model LightGBMXT_BAG_L2/T1. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/LightGBMXT_BAG_L2/T1 will be removed.
# Deleting model LightGBMXT_BAG_L2/T2. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/LightGBMXT_BAG_L2/T2 will be removed.
# Deleting model LightGBMXT_BAG_L2/T3. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/LightGBMXT_BAG_L2/T3 will be removed.
# Deleting model LightGBMXT_BAG_L2/T4. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/LightGBMXT_BAG_L2/T4 will be removed.
# Deleting model LightGBMXT_BAG_L2/T5. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/LightGBMXT_BAG_L2/T5 will be removed.
# Deleting model LightGBMXT_BAG_L2/T6. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/LightGBMXT_BAG_L2/T6 will be removed.
# Deleting model LightGBM_BAG_L2/T1. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/LightGBM_BAG_L2/T1 will be removed.
# Deleting model LightGBM_BAG_L2/T2. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/LightGBM_BAG_L2/T2 will be removed.
# Deleting model LightGBM_BAG_L2/T3. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/LightGBM_BAG_L2/T3 will be removed.
# Deleting model RandomForestGini_BAG_L2. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/RandomForestGini_BAG_L2 will be removed.
# Deleting model RandomForestEntr_BAG_L2. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/RandomForestEntr_BAG_L2 will be removed.
# Deleting model CatBoost_BAG_L2/T1. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/CatBoost_BAG_L2/T1 will be removed.
# Deleting model CatBoost_BAG_L2/T2. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/CatBoost_BAG_L2/T2 will be removed.
# Deleting model CatBoost_BAG_L2/T3. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/CatBoost_BAG_L2/T3 will be removed.
# Deleting model ExtraTreesGini_BAG_L2. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/ExtraTreesGini_BAG_L2 will be removed.
# Deleting model ExtraTreesEntr_BAG_L2. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/ExtraTreesEntr_BAG_L2 will be removed.
# Deleting model NeuralNetFastAI_BAG_L2/fbf43ee6. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L2/fbf43ee6 will be removed.
# Deleting model NeuralNetFastAI_BAG_L2/33443946. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L2/33443946 will be removed.
# Deleting model NeuralNetFastAI_BAG_L2/a34016b0. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L2/a34016b0 will be removed.
# Deleting model NeuralNetFastAI_BAG_L2/25014763. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L2/25014763 will be removed.
# Deleting model NeuralNetFastAI_BAG_L2/243e3879. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L2/243e3879 will be removed.
# Deleting model NeuralNetFastAI_BAG_L2/58e66ad2. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L2/58e66ad2 will be removed.
# Deleting model NeuralNetFastAI_BAG_L2/aeaeb1d2. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L2/aeaeb1d2 will be removed.
# Deleting model NeuralNetFastAI_BAG_L2/093d235b. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L2/093d235b will be removed.
# Deleting model NeuralNetFastAI_BAG_L2/a11e2489. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L2/a11e2489 will be removed.
# Deleting model NeuralNetFastAI_BAG_L2/8698089d. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L2/8698089d will be removed.
# Deleting model NeuralNetFastAI_BAG_L2/40b6d093. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L2/40b6d093 will be removed.
# Deleting model NeuralNetFastAI_BAG_L2/f009b26f. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L2/f009b26f will be removed.
# Deleting model NeuralNetFastAI_BAG_L2/a2584c28. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L2/a2584c28 will be removed.
# Deleting model NeuralNetFastAI_BAG_L2/ab746a4b. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L2/ab746a4b will be removed.
# Deleting model NeuralNetFastAI_BAG_L2/160ab05d. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L2/160ab05d will be removed.
# Deleting model NeuralNetFastAI_BAG_L2/302e030a. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L2/302e030a will be removed.
# Deleting model XGBoost_BAG_L2/T1. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/XGBoost_BAG_L2/T1 will be removed.
# Deleting model XGBoost_BAG_L2/T2. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/XGBoost_BAG_L2/T2 will be removed.
# Deleting model XGBoost_BAG_L2/T3. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/XGBoost_BAG_L2/T3 will be removed.
# Deleting model NeuralNetTorch_BAG_L2/1271de59. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetTorch_BAG_L2/1271de59 will be removed.
# Deleting model NeuralNetTorch_BAG_L2/8964517e. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetTorch_BAG_L2/8964517e will be removed.
# Deleting model NeuralNetTorch_BAG_L2/634e5bce. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetTorch_BAG_L2/634e5bce will be removed.
# Deleting model LightGBMLarge_BAG_L2. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/LightGBMLarge_BAG_L2 will be removed.
# Deleting model WeightedEnsemble_L3. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/WeightedEnsemble_L3 will be removed.
# Deleting model LightGBMXT_BAG_L1/T1_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/LightGBMXT_BAG_L1/T1_FULL will be removed.
# Deleting model LightGBMXT_BAG_L1/T2_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/LightGBMXT_BAG_L1/T2_FULL will be removed.
# Deleting model LightGBMXT_BAG_L1/T4_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/LightGBMXT_BAG_L1/T4_FULL will be removed.
# Deleting model LightGBMXT_BAG_L1/T6_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/LightGBMXT_BAG_L1/T6_FULL will be removed.
# Deleting model LightGBMXT_BAG_L1/T8_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/LightGBMXT_BAG_L1/T8_FULL will be removed.
# Deleting model LightGBM_BAG_L1/T1_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/LightGBM_BAG_L1/T1_FULL will be removed.
# Deleting model LightGBM_BAG_L1/T2_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/LightGBM_BAG_L1/T2_FULL will be removed.
# Deleting model LightGBM_BAG_L1/T3_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/LightGBM_BAG_L1/T3_FULL will be removed.
# Deleting model LightGBM_BAG_L1/T4_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/LightGBM_BAG_L1/T4_FULL will be removed.
# Deleting model LightGBM_BAG_L1/T5_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/LightGBM_BAG_L1/T5_FULL will be removed.
# Deleting model NeuralNetFastAI_BAG_L1/8d559b59_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L1/8d559b59_FULL will be removed.
# Deleting model NeuralNetFastAI_BAG_L1/45914bf2_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L1/45914bf2_FULL will be removed.
# Deleting model NeuralNetFastAI_BAG_L1/b2b01ccf_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L1/b2b01ccf_FULL will be removed.
# Deleting model NeuralNetFastAI_BAG_L1/307c0815_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L1/307c0815_FULL will be removed.
# Deleting model NeuralNetFastAI_BAG_L1/2a9f22d6_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L1/2a9f22d6_FULL will be removed.
# Deleting model NeuralNetFastAI_BAG_L1/48db6f1f_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L1/48db6f1f_FULL will be removed.
# Deleting model NeuralNetFastAI_BAG_L1/9dabaff2_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L1/9dabaff2_FULL will be removed.
# Deleting model NeuralNetFastAI_BAG_L1/666b86c6_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L1/666b86c6_FULL will be removed.
# Deleting model NeuralNetFastAI_BAG_L1/22d73b5f_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L1/22d73b5f_FULL will be removed.
# Deleting model NeuralNetFastAI_BAG_L1/f29e63b3_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L1/f29e63b3_FULL will be removed.
# Deleting model NeuralNetFastAI_BAG_L1/1f05f137_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L1/1f05f137_FULL will be removed.
# Deleting model NeuralNetFastAI_BAG_L1/bbf5f6a0_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L1/bbf5f6a0_FULL will be removed.
# Deleting model XGBoost_BAG_L1/T3_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/XGBoost_BAG_L1/T3_FULL will be removed.
# Deleting model NeuralNetTorch_BAG_L1/9017436a_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetTorch_BAG_L1/9017436a_FULL will be removed.
# Deleting model NeuralNetTorch_BAG_L1/e579f4c4_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetTorch_BAG_L1/e579f4c4_FULL will be removed.
# Deleting model NeuralNetTorch_BAG_L1/6fbe0414_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetTorch_BAG_L1/6fbe0414_FULL will be removed.
# Deleting model LightGBMLarge_BAG_L1_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/LightGBMLarge_BAG_L1_FULL will be removed.
# Deleting model WeightedEnsemble_L2_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/WeightedEnsemble_L2_FULL will be removed.
# Deleting model LightGBMXT_BAG_L2/T1_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/LightGBMXT_BAG_L2/T1_FULL will be removed.
# Deleting model LightGBMXT_BAG_L2/T2_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/LightGBMXT_BAG_L2/T2_FULL will be removed.
# Deleting model LightGBMXT_BAG_L2/T3_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/LightGBMXT_BAG_L2/T3_FULL will be removed.
# Deleting model LightGBMXT_BAG_L2/T4_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/LightGBMXT_BAG_L2/T4_FULL will be removed.
# Deleting model LightGBM_BAG_L2/T1_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/LightGBM_BAG_L2/T1_FULL will be removed.
# Deleting model LightGBM_BAG_L2/T2_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/LightGBM_BAG_L2/T2_FULL will be removed.
# Deleting model LightGBM_BAG_L2/T3_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/LightGBM_BAG_L2/T3_FULL will be removed.
# Deleting model RandomForestGini_BAG_L2_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/RandomForestGini_BAG_L2_FULL will be removed.
# Deleting model RandomForestEntr_BAG_L2_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/RandomForestEntr_BAG_L2_FULL will be removed.
# Deleting model CatBoost_BAG_L2/T2_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/CatBoost_BAG_L2/T2_FULL will be removed.
# Deleting model ExtraTreesGini_BAG_L2_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/ExtraTreesGini_BAG_L2_FULL will be removed.
# Deleting model ExtraTreesEntr_BAG_L2_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/ExtraTreesEntr_BAG_L2_FULL will be removed.
# Deleting model NeuralNetFastAI_BAG_L2/fbf43ee6_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L2/fbf43ee6_FULL will be removed.
# Deleting model NeuralNetFastAI_BAG_L2/33443946_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L2/33443946_FULL will be removed.
# Deleting model NeuralNetFastAI_BAG_L2/a34016b0_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L2/a34016b0_FULL will be removed.
# Deleting model NeuralNetFastAI_BAG_L2/25014763_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L2/25014763_FULL will be removed.
# Deleting model NeuralNetFastAI_BAG_L2/243e3879_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L2/243e3879_FULL will be removed.
# Deleting model NeuralNetFastAI_BAG_L2/58e66ad2_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L2/58e66ad2_FULL will be removed.
# Deleting model NeuralNetFastAI_BAG_L2/aeaeb1d2_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L2/aeaeb1d2_FULL will be removed.
# Deleting model NeuralNetFastAI_BAG_L2/a11e2489_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L2/a11e2489_FULL will be removed.
# Deleting model NeuralNetFastAI_BAG_L2/40b6d093_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L2/40b6d093_FULL will be removed.
# Deleting model NeuralNetFastAI_BAG_L2/f009b26f_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L2/f009b26f_FULL will be removed.
# Deleting model NeuralNetFastAI_BAG_L2/a2584c28_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L2/a2584c28_FULL will be removed.
# Deleting model NeuralNetFastAI_BAG_L2/ab746a4b_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L2/ab746a4b_FULL will be removed.
# Deleting model NeuralNetFastAI_BAG_L2/160ab05d_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L2/160ab05d_FULL will be removed.
# Deleting model NeuralNetFastAI_BAG_L2/302e030a_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L2/302e030a_FULL will be removed.
# Deleting model XGBoost_BAG_L2/T1_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/XGBoost_BAG_L2/T1_FULL will be removed.
# Deleting model XGBoost_BAG_L2/T2_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/XGBoost_BAG_L2/T2_FULL will be removed.
# Deleting model XGBoost_BAG_L2/T3_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/XGBoost_BAG_L2/T3_FULL will be removed.
# Deleting model NeuralNetTorch_BAG_L2/8964517e_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetTorch_BAG_L2/8964517e_FULL will be removed.
# Deleting model NeuralNetTorch_BAG_L2/634e5bce_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetTorch_BAG_L2/634e5bce_FULL will be removed.
# Deleting model LightGBMLarge_BAG_L2_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/LightGBMLarge_BAG_L2_FULL will be removed.
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("/home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1")

# %% [markdown]
# ## Test Set Evaluation (Best Model)

# %%
y_test_pred = predictor.predict(X_test)

metrics = {
    "accuracy": accuracy_score(y_test, y_test_pred),
    "balanced_accuracy": balanced_accuracy_score(y_test, y_test_pred),
    "precision": precision_score(y_test, y_test_pred),
    "recall": recall_score(y_test, y_test_pred),
    "f1": f1_score(y_test, y_test_pred),
    "error_rate": 1 - accuracy_score(y_test, y_test_pred),
}

pd.Series(metrics).round(4)
# Out:
# accuracy             0.5253
# balanced_accuracy    0.5261
# precision            0.5046
# recall               0.5452
# f1                   0.5241
# error_rate           0.4747
# dtype: float64

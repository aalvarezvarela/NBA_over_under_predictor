# %% [markdown]
# # Classification NBA Model

# %% [markdown]
# ## Configuration

# %%
from pathlib import Path

save_models_path = "/home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/"
Path(save_models_path).mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ## Imports

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from autogluon.tabular import TabularPredictor
from nba_ou.data_preparation.missing_data.handle_missing_data import (
    apply_missing_policy,
)
from sklearn.dummy import DummyClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import (
    accuracy_score,
    balanced_accuracy_score,
    confusion_matrix,
    f1_score,
    make_scorer,
    precision_score,
    recall_score,
)
from sklearn.model_selection import KFold, cross_validate, train_test_split
from xgboost import XGBClassifier

# %% [markdown]
# ## Load Data

# %%
data_path = "/home/adrian_alvarez/Projects/NBA_over_under_predictor/data/train_data/"
name = "all_odds_training_data_until_20260110.csv"

path = data_path + name

df_stats = pd.read_csv(path)

dtype_dict = {col: str for col in df_stats.columns if "ID" in col.upper()}

df_stats = pd.read_csv(
    path,
    dtype=dtype_dict
)
df_stats['GAME_DATE'] = pd.to_datetime(df_stats['GAME_DATE']).dt.strftime('%Y-%m-%d')
# Out:
# /tmp/ipykernel_1012249/2663114250.py:6: DtypeWarning: Columns (204,205,206,207,247,248,249,250,290,291,292,293,333,334,335,336,376,377,378,379,419,420,421,422,615,616,617,618,658,659,660,661,701,702,703,704,744,745,746,747,787,788,789,790,830,831,832,833) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_stats = pd.read_csv(path)
# /tmp/ipykernel_1012249/2663114250.py:10: DtypeWarning: Columns (204,205,206,207,247,248,249,250,290,291,292,293,333,334,335,336,376,377,378,379,419,420,421,422,615,616,617,618,658,659,660,661,701,702,703,704,744,745,746,747,787,788,789,790,830,831,832,833) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_stats = pd.read_csv(

# %%
from nba_ou.data_preparation.missing_data.clean_df_for_training import (
    clean_dataframe_for_training
)
df_to_train = clean_dataframe_for_training(df_stats, nan_threshold=4, drop_all_na_rows=True, verbose=1)
# Out:
# ================================================================================
# STARTING DATAFRAME CLEANING PIPELINE
# ================================================================================
# Starting basic cleaning with 10794 rows
# Basic cleaning complete: 7976 rows remaining
#
# Starting advanced column cleaning with 1133 columns
#
# Advanced column cleaning complete: 1133 → 660 columns (473 removed)
#
#
# Applying missing data policy...
#
# Missing Data Policy Report:
#   Rows dropped: 0 (0.0%)
#   Critical columns requiring data: 5
#   Columns zero-filled: 132
#   Infer pairs applied: 54/228
#   Remaining NaN cells: 144
#
# Dropping rows that are all NaN...
# ================================================================================
# CLEANING COMPLETE
# Final shape: (7957, 660)
# ================================================================================

# %%
# Count NAs per column
na_counts = df_to_train.isna().sum()

# Get most common SEASON_YEAR for nulls in each column
most_common_season = []
for col in df_to_train.columns:
    if na_counts[col] > 0:
        # Get rows where this column is null
        null_rows = df_stats[df_stats[col].isna()]
        if len(null_rows) > 0 and 'SEASON_YEAR' in df_stats.columns:
            # Find most common SEASON_YEAR for these null rows
            common_season = null_rows['SEASON_YEAR'].mode()
            most_common_season.append(common_season.iloc[0] if len(common_season) > 0 else None)
        else:
            most_common_season.append(None)
    else:
        most_common_season.append(None)

na_counts_df = pd.DataFrame({
    'Column': na_counts.index,
    'NA_Count': na_counts.values,
    'NA_Percentage': (na_counts.values / len(df_to_train) * 100).round(2),
    'Most_Common_Season_Year': most_common_season
}).sort_values('NA_Count', ascending=False)

# Show only columns with NAs
na_counts_df[na_counts_df['NA_Count'] > 0]
# Out:
# Empty DataFrame
# Columns: [Column, NA_Count, NA_Percentage, Most_Common_Season_Year]
# Index: []

# %%
df_to_train = df_to_train[df_to_train['TOTAL_POINTS'] != df_to_train['TOTAL_OVER_UNDER_LINE']]

# %%
df_to_train['OVER_UNDER'] = np.where(df_to_train['TOTAL_POINTS'] >= df_to_train['TOTAL_OVER_UNDER_LINE'], 1, 0) # 1 if over, 0 if under

# %%
#count 1 and 0 in OVER_UNDER
df_to_train['OVER_UNDER'].value_counts()
# Out:
# OVER_UNDER
# 0    4070
# 1    3792
# Name: count, dtype: int64

# %%
df_to_train= df_to_train[df_to_train['SEASON_YEAR'] != 2018]

# %% [markdown]
# ## Train / Test

# %%
X = df_to_train.drop(['TOTAL_POINTS', 'OVER_UNDER', 'SEASON_YEAR'], axis=1, errors='ignore')
y = df_to_train['OVER_UNDER']

# %%
# Train / Test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=16)

# %%
df_to_train['IS_TRAINING_DATA'] = False

# Mark True for the rows in the training set
df_to_train.loc[X_train.index, 'IS_TRAINING_DATA'] = True
# output_name = f"{data_path}/training_data_with_missing_data_handled_from_2004-10-01_to_2026-01-10_classifier.csv"
# df_to_train.to_csv(output_name, index=False)

# %%
print(f"Training set size: {X_train.shape[0]}")
print(f"Test set size: {X_test.shape[0]}")
# Check number of coulmns
print(f"Number of columns in training set: {X_train.shape[1]}")
print(f"Number of columns in test set: {X_test.shape[1]}")
# Out:
# Training set size: 5883
# Test set size: 1962
# Number of columns in training set: 658
# Number of columns in test set: 658

# %% [markdown]
# ## Cross-validation

# %%
# Declare KFold
kf = KFold(n_splits=5, shuffle=True, random_state=16)

# %%
# Declare scores to be used
scoring = {
    'Acc': make_scorer(accuracy_score),
    'Prec': make_scorer(precision_score),
    'Rec': make_scorer(recall_score),
    'Bacc': make_scorer(balanced_accuracy_score),
}

# %%
def print_classification_metrics(cv_results, scoring):
    """
    Prints the mean cross-validation scores for each metric on train and validation folds.
    """
    for sc in scoring.keys():
        print(f"Train {sc}:", cv_results[f'train_{sc}'].mean().round(5))
        print(f"Validation {sc}:", cv_results[f'test_{sc}'].mean().round(5))
        print()

# %% [markdown]
# ## Baseline

# %%
dummy_clf = DummyClassifier(strategy='most_frequent')
cv_results = cross_validate(
    dummy_clf, 
    X_train, 
    y_train, 
    cv=kf, 
    scoring=scoring, 
    return_train_score=True
)
dummy_clf.fit(X_train, y_train)
print("=== Dummy (Most Frequent) Classifier ===")
print_classification_metrics(cv_results, scoring)
# Out:
# === Dummy (Most Frequent) Classifier ===
# Train Acc: 0.50518
# Validation Acc: 0.50518
#
# Train Prec: 0.0
# Validation Prec: 0.0
#
# Train Rec: 0.0
# Validation Rec: 0.0
#
# Train Bacc: 0.5
# Validation Bacc: 0.5
# /home/adrian_alvarez/Projects/NBA_over_under_predictor/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/adrian_alvarez/Projects/NBA_over_under_predictor/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/adrian_alvarez/Projects/NBA_over_under_predictor/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/adrian_alvarez/Projects/NBA_over_under_predictor/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/adrian_alvarez/Projects/NBA_over_under_predictor/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/adrian_alvarez/Projects/NBA_over_under_predictor/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/adrian_alvarez/Projects/NBA_over_under_predictor/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/adrian_alvarez/Projects/NBA_over_under_predictor/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/adrian_alvarez/Projects/NBA_over_under_predictor/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/adrian_alvarez/Projects/NBA_over_under_predictor/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# ## Logistic Regression

# %%
lr = LogisticRegression(max_iter=1000)
cv_results = cross_validate(
    lr, 
    X_train, 
    y_train, 
    cv=kf, 
    scoring=scoring, 
    return_train_score=True,
    n_jobs=-1
)
lr.fit(X_train, y_train)
# Out:
# /home/adrian_alvarez/Projects/NBA_over_under_predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/adrian_alvarez/Projects/NBA_over_under_predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/adrian_alvarez/Projects/NBA_over_under_predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/adrian_alvarez/Projects/NBA_over_under_predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/adrian_alvarez/Projects/NBA_over_under_predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/adrian_alvarez/Projects/NBA_over_under_predictor/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(max_iter=1000)

# %%
print("=== Logistic Regression ===")
print_classification_metrics(cv_results, scoring)
# Out:
# === Logistic Regression ===
# Train Acc: 0.63148
# Validation Acc: 0.53068
#
# Train Prec: 0.62813
# Validation Prec: 0.52602
#
# Train Rec: 0.62551
# Validation Rec: 0.52804
#
# Train Bacc: 0.63137
# Validation Bacc: 0.53094

# %%
xgb_clf = XGBClassifier(
    max_depth=5,
    learning_rate=0.025,
    n_estimators=350,
    subsample=0.6,
    colsample_bytree=0.8,
    n_jobs=-1,
    random_state=16
)

cv_results = cross_validate(
    xgb_clf, 
    X_train, 
    y_train, 
    cv=kf, 
    scoring=scoring, 
    return_train_score=True,
    n_jobs=-1
)

xgb_clf.fit(X_train, y_train)

print("=== XGBClassifier ===")
print_classification_metrics(cv_results, scoring)
# Out:
# === XGBClassifier ===
# Train Acc: 0.98955
# Validation Acc: 0.51997
#
# Train Prec: 0.99046
# Validation Prec: 0.51556
#
# Train Rec: 0.98841
# Validation Rec: 0.51312
#
# Train Bacc: 0.98954
# Validation Bacc: 0.52021

# %%
# Calcualte it in test set
y_pred = xgb_clf.predict(X_test)

#Predict test set with XGBClassifier
y_pred = xgb_clf.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
balan_acc = balanced_accuracy_score(y_test, y_pred)
print("=== XGBClassifier Test Set Performance ===")
print(f"Accuracy: {accuracy:.5f}")
print(f"Precision: {precision:.5f}")    
print(f"Recall: {recall:.5f}")
print(f"F1 Score: {f1:.5f}")
print(f"Balanced Accuracy: {balan_acc:.5f}")

#groupby season_year and calculate accuracy per season
df_test = X_test.copy()
df_test['TRUE_LABEL'] = y_test
df_test['PRED_LABEL'] = y_pred
df_test['CORRECT_PREDICTION'] = np.where(df_test['TRUE_LABEL'] == df_test['PRED_LABEL'], 1, 0)
#merge 'SEASON_YEAR' from df_to_train
df_test = df_test.merge(df_to_train[['SEASON_YEAR']], left_index=True, right_index=True, how='left')
season_accuracy = df_test.groupby('SEASON_YEAR')['CORRECT_PREDICTION'].mean().reset_index()
season_accuracy.rename(columns={'CORRECT_PREDICTION': 'ACCURACY'}, inplace=True)
print("=== Test Set Accuracy by Season ===")
print(season_accuracy)
# Out:
# === XGBClassifier Test Set Performance ===
# Accuracy: 0.52345
# Precision: 0.46638
# Recall: 0.50115
# F1 Score: 0.48314
# Balanced Accuracy: 0.52122
# === Test Set Accuracy by Season ===
#    SEASON_YEAR  ACCURACY
# 0         2019  0.504505
# 1         2020  0.547619
# 2         2021  0.528875
# 3         2022  0.543689
# 4         2023  0.493243
# 5         2024  0.476839
# 6         2025  0.627586

# %% [markdown]
# ## AutoGluon (Hyperparameter Tuning)

# %%
predictor = TabularPredictor(
    label="target",
    problem_type="binary",
    eval_metric="balanced_accuracy",
    path=save_models_path,
).fit(
    train_data=X_train.assign(target=y_train),
    time_limit=14_000,
    presets="good_quality",
    hyperparameter_tune_kwargs="auto",
    num_cpus=12,
    # hyperparameters={
    #     "XGB": {},  # only XGBoost models
    # },
)
# Out:
# 2026-02-03 23:36:07,864	INFO timeout.py:54 -- Reached timeout of 936.6289839831265 seconds. Stopping all trials.
# 2026-02-03 23:36:07,880	INFO tune.py:1009 -- Wrote the latest version of all result files and experiment state to '/home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetTorch_BAG_L1' in 0.0128s.
# 2026-02-03 23:36:07,940	WARNING experiment_analysis.py:180 -- Failed to fetch metrics for 15 trial(s):
# - 61e10f1f: FileNotFoundError('Could not fetch metrics for 61e10f1f: both result.json and progress.csv were not found at /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetTorch_BAG_L1/61e10f1f')
# - 3f7e583d: FileNotFoundError('Could not fetch metrics for 3f7e583d: both result.json and progress.csv were not found at /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetTorch_BAG_L1/3f7e583d')
# - 35f2f9bb: FileNotFoundError('Could not fetch metrics for 35f2f9bb: both result.json and progress.csv were not found at /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetTorch_BAG_L1/35f2f9bb')
# - 27f64188: FileNotFoundError('Could not fetch metrics for 27f64188: both result.json and progress.csv were not found at /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetTorch_BAG_L1/27f64188')
# - 4b0b353f: FileNotFoundError('Could not fetch metrics for 4b0b353f: both result.json and progress.csv were not found at /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetTorch_BAG_L1/4b0b353f')
# - 0de333c1: FileNotFoundError('Could not fetch metrics for 0de333c1: both result.json and progress.csv were not found at /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetTorch_BAG_L1/0de333c1')
# - 34528cfb: FileNotFoundError('Could not fetch metrics for 34528cfb: both result.json and progress.csv were not found at /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetTorch_BAG_L1/34528cfb')
# - a08c6a8d: FileNotFoundError('Could not fetch metrics for a08c6a8d: both result.json and progress.csv were not found at /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetTorch_BAG_L1/a08c6a8d')
# - 6f1d2692: FileNotFoundError('Could not fetch metrics for 6f1d2692: both result.json and progress.csv were not found at /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetTorch_BAG_L1/6f1d2692')
# - a3bdf838: FileNotFoundError('Could not fetch metrics for a3bdf838: both result.json and progress.csv were not found at /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetTorch_BAG_L1/a3bdf838')
# - 8a6e7925: FileNotFoundError('Could not fetch metrics for 8a6e7925: both result.json and progress.csv were not found at /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetTorch_BAG_L1/8a6e7925')
# - 6bb37649: FileNotFoundError('Could not fetch metrics for 6bb37649: both result.json and progress.csv were not found at /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetTorch_BAG_L1/6bb37649')
# - 2fed4639: FileNotFoundError('Could not fetch metrics for 2fed4639: both result.json and progress.csv were not found at /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetTorch_BAG_L1/2fed4639')
# - 6959c7d4: FileNotFoundError('Could not fetch metrics for 6959c7d4: both result.json and progress.csv were not found at /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetTorch_BAG_L1/6959c7d4')
# - 682d4106: FileNotFoundError('Could not fetch metrics for 682d4106: both result.json and progress.csv were not found at /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetTorch_BAG_L1/682d4106')
# Fitted model: NeuralNetTorch_BAG_L1/61e10f1f ...
# 	0.5446	 = Validation score   (balanced_accuracy)
# 	37.37s	 = Training   runtime
# 	0.78s	 = Validation runtime
# Fitted model: NeuralNetTorch_BAG_L1/3f7e583d ...
# 	0.5001	 = Validation score   (balanced_accuracy)
# 	134.12s	 = Training   runtime
# 	0.2s	 = Validation runtime
# Fitted model: NeuralNetTorch_BAG_L1/35f2f9bb ...
# 	0.5073	 = Validation score   (balanced_accuracy)
# 	87.4s	 = Training   runtime
# 	0.8s	 = Validation runtime
# Fitted model: NeuralNetTorch_BAG_L1/27f64188 ...
# 	0.5174	 = Validation score   (balanced_accuracy)
# 	47.34s	 = Training   runtime
# 	0.74s	 = Validation runtime
# Fitted model: NeuralNetTorch_BAG_L1/4b0b353f ...
# 	0.5514	 = Validation score   (balanced_accuracy)
# 	40.74s	 = Training   runtime
# 	0.63s	 = Validation runtime
# Fitted model: NeuralNetTorch_BAG_L1/0de333c1 ...
# 	0.5579	 = Validation score   (balanced_accuracy)
# 	58.57s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Fitted model: NeuralNetTorch_BAG_L1/34528cfb ...
# 	0.5008	 = Validation score   (balanced_accuracy)
# 	57.52s	 = Training   runtime
# 	0.92s	 = Validation runtime
# Fitted model: NeuralNetTorch_BAG_L1/a08c6a8d ...
# 	0.5541	 = Validation score   (balanced_accuracy)
# 	55.14s	 = Training   runtime
# 	1.14s	 = Validation runtime
# Fitted model: NeuralNetTorch_BAG_L1/6f1d2692 ...
# 	0.5219	 = Validation score   (balanced_accuracy)
# 	138.4s	 = Training   runtime
# 	1.32s	 = Validation runtime
# Fitted model: NeuralNetTorch_BAG_L1/a3bdf838 ...
# 	0.5536	 = Validation score   (balanced_accuracy)
# 	38.85s	 = Training   runtime
# 	0.32s	 = Validation runtime
# Fitted model: NeuralNetTorch_BAG_L1/8a6e7925 ...
# 	0.5089	 = Validation score   (balanced_accuracy)
# 	68.98s	 = Training   runtime
# 	1.16s	 = Validation runtime
# Fitted model: NeuralNetTorch_BAG_L1/6bb37649 ...
# 	0.5555	 = Validation score   (balanced_accuracy)
# 	83.67s	 = Training   runtime
# 	0.88s	 = Validation runtime
# Fitted model: NeuralNetTorch_BAG_L1/2fed4639 ...
# 	0.5465	 = Validation score   (balanced_accuracy)
# 	35.96s	 = Training   runtime
# 	1.35s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 936.63s of the 6071.28s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=3.32%)
# 	0.5437	 = Validation score   (balanced_accuracy)
# 	181.49s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 1144.77s of the 5886.69s of remaining time.
# 	Fitting 1 model on all data | Fitting with cpus=12, gpus=0, mem=0.0/21.2 GB
# 	Ensemble Weights: {'XGBoost_BAG_L1/T2': 1.0}
# 	0.5581	 = Validation score   (balanced_accuracy)
# 	0.1s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 5561.83s ... Best model: WeightedEnsemble_L2 | Estimated inference throughput: 2890.5 rows/s (502 batch size)
# Automatically performing refit_full as a post-fit operation (due to `.fit(..., refit_full=True)`
# Refitting models via `predictor.refit_full` using all of the data (combined train and validation)...
# 	Models trained in this way will have the suffix "_FULL" and have NaN validation score.
# 	This process is not bound by time_limit, but should take less time than the original `predictor.fit` call.
# 	To learn more, refer to the `.refit_full` method docstring which explains how "_FULL" models differ from normal models.
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_BAG_L1/T1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=12, gpus=0, mem=0.2/21.3 GB
# 	1.83s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_BAG_L1/T2_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=12, gpus=0, mem=0.4/21.6 GB
# 	6.0s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_BAG_L1/T3_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=12, gpus=0, mem=0.3/21.5 GB
# 	1.29s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_BAG_L1/T4_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=12, gpus=0, mem=0.4/21.5 GB
# 	2.96s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_BAG_L1/T5_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=12, gpus=0, mem=0.3/21.5 GB
# 	2.99s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_BAG_L1/T6_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=12, gpus=0, mem=0.5/21.5 GB
# 	3.45s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_BAG_L1/T7_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=12, gpus=0, mem=0.4/21.5 GB
# 	1.86s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_BAG_L1/T8_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=12, gpus=0, mem=0.3/21.5 GB
# 	1.55s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_BAG_L1/T9_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=12, gpus=0, mem=0.4/21.5 GB
# 	4.57s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_BAG_L1/T10_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=12, gpus=0, mem=0.4/21.4 GB
# 	3.47s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_BAG_L1/T11_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=12, gpus=0, mem=0.4/21.5 GB
# 	2.59s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_BAG_L1/T12_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=12, gpus=0, mem=0.4/21.5 GB
# 	3.95s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_BAG_L1/T13_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=12, gpus=0, mem=0.5/21.4 GB
# 	3.74s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_BAG_L1/T14_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=12, gpus=0, mem=0.2/21.4 GB
# 	2.28s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_BAG_L1/T15_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=12, gpus=0, mem=0.2/21.4 GB
# 	3.05s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_BAG_L1/T16_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=12, gpus=0, mem=0.4/21.4 GB
# 	4.68s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_BAG_L1/T17_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=12, gpus=0, mem=0.4/21.4 GB
# 	4.57s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_BAG_L1/T18_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=12, gpus=0, mem=0.2/21.4 GB
# 	1.24s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_BAG_L1/T19_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=12, gpus=0, mem=0.2/21.4 GB
# 	2.99s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_BAG_L1/T20_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=12, gpus=0, mem=0.2/21.4 GB
# 	2.23s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_BAG_L1/T21_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=12, gpus=0, mem=0.3/21.4 GB
# 	4.0s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_BAG_L1/T1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=12, gpus=0, mem=0.2/21.4 GB
# 	1.81s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_BAG_L1/T2_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=12, gpus=0, mem=0.4/21.5 GB
# 	10.53s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_BAG_L1/T3_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=12, gpus=0, mem=0.3/21.5 GB
# 	4.3s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_BAG_L1/T4_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=12, gpus=0, mem=0.4/21.5 GB
# 	10.78s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_BAG_L1/T5_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=12, gpus=0, mem=0.3/21.5 GB
# 	3.11s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_BAG_L1/T6_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=12, gpus=0, mem=0.5/21.5 GB
# 	8.68s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_BAG_L1/T7_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=12, gpus=0, mem=0.4/21.5 GB
# 	2.97s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_BAG_L1/T8_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=12, gpus=0, mem=0.3/21.5 GB
# 	3.54s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBM_BAG_L1/T9_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=12, gpus=0, mem=0.4/21.5 GB
# 	3.31s	 = Training   runtime
# Fitting model: RandomForestGini_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	5.41s	 = Training   runtime
# 	0.81s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	6.84s	 = Training   runtime
# 	0.79s	 = Validation runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_BAG_L1/T1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=12, gpus=0, mem=1.0/21.5 GB
# 	4.98s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_BAG_L1/T2_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=12, gpus=0
# 	1.89s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: CatBoost_BAG_L1/T3_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=12, gpus=0, mem=1.6/21.3 GB
# 	28.46s	 = Training   runtime
# Fitting model: ExtraTreesGini_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	1.06s	 = Training   runtime
# 	0.6s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	0.97s	 = Training   runtime
# 	0.6s	 = Validation runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_BAG_L1/bd81d8e4_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.2/21.4 GB
# Metric balanced_accuracy is not supported by this model - using log_loss instead
# 	Stopping at the best epoch learned earlier - 0.
# 	0.47s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_BAG_L1/2b7edef2_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.2/21.4 GB
# Metric balanced_accuracy is not supported by this model - using log_loss instead
# 	Stopping at the best epoch learned earlier - 0.
# 	1.01s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_BAG_L1/ecd71730_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.2/21.3 GB
# Metric balanced_accuracy is not supported by this model - using log_loss instead
# 	Stopping at the best epoch learned earlier - 0.
# 	0.82s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_BAG_L1/dffc69e3_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.2/21.3 GB
# Metric balanced_accuracy is not supported by this model - using log_loss instead
# 	Stopping at the best epoch learned earlier - 4.
# 	3.66s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_BAG_L1/f37d82ee_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.2/21.3 GB
# Metric balanced_accuracy is not supported by this model - using log_loss instead
# 	Stopping at the best epoch learned earlier - 2.
# 	2.09s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_BAG_L1/06cccef4_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.2/21.3 GB
# Metric balanced_accuracy is not supported by this model - using log_loss instead
# 	Stopping at the best epoch learned earlier - 0.
# 	0.72s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_BAG_L1/5a40119d_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.2/21.3 GB
# Metric balanced_accuracy is not supported by this model - using log_loss instead
# 	Stopping at the best epoch learned earlier - 9.
# 	3.48s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_BAG_L1/6963845e_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.2/21.2 GB
# Metric balanced_accuracy is not supported by this model - using log_loss instead
# 	Stopping at the best epoch learned earlier - 1.
# 	0.99s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_BAG_L1/7d4cff15_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.2/21.4 GB
# Metric balanced_accuracy is not supported by this model - using log_loss instead
# 	Stopping at the best epoch learned earlier - 3.
# 	3.93s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_BAG_L1/fe2bff87_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.2/21.3 GB
# Metric balanced_accuracy is not supported by this model - using log_loss instead
# 	Stopping at the best epoch learned earlier - 2.
# 	4.34s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_BAG_L1/f0e99916_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.2/21.3 GB
# Metric balanced_accuracy is not supported by this model - using log_loss instead
# 	Stopping at the best epoch learned earlier - 3.
# 	0.8s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_BAG_L1/fcfe898d_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.2/21.2 GB
# Metric balanced_accuracy is not supported by this model - using log_loss instead
# 	Stopping at the best epoch learned earlier - 0.
# 	0.95s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_BAG_L1/a0ee84c2_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.2/21.2 GB
# Metric balanced_accuracy is not supported by this model - using log_loss instead
# 	Stopping at the best epoch learned earlier - 0.
# 	0.43s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_BAG_L1/5be9439d_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.2/21.2 GB
# Metric balanced_accuracy is not supported by this model - using log_loss instead
# 	Stopping at the best epoch learned earlier - 1.
# 	0.41s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_BAG_L1/e92ab7ec_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.2/21.2 GB
# Metric balanced_accuracy is not supported by this model - using log_loss instead
# 	Stopping at the best epoch learned earlier - 0.
# 	0.42s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_BAG_L1/062d6a1a_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.2/21.2 GB
# Metric balanced_accuracy is not supported by this model - using log_loss instead
# 	Stopping at the best epoch learned earlier - 3.
# 	0.59s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_BAG_L1/10089b41_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.2/21.2 GB
# Metric balanced_accuracy is not supported by this model - using log_loss instead
# 	Stopping at the best epoch learned earlier - 4.
# 	0.59s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_BAG_L1/07ff95e4_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.2/21.2 GB
# Metric balanced_accuracy is not supported by this model - using log_loss instead
# 	Stopping at the best epoch learned earlier - 6.
# 	1.67s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_BAG_L1/369f8116_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.2/21.2 GB
# Metric balanced_accuracy is not supported by this model - using log_loss instead
# 	Stopping at the best epoch learned earlier - 0.
# 	0.42s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_BAG_L1/6826ae72_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.2/21.2 GB
# Metric balanced_accuracy is not supported by this model - using log_loss instead
# 	Stopping at the best epoch learned earlier - 1.
# 	0.75s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_BAG_L1/124d7b3b_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.2/21.2 GB
# Metric balanced_accuracy is not supported by this model - using log_loss instead
# 	Stopping at the best epoch learned earlier - 2.
# 	2.59s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_BAG_L1/40debbcc_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.2/21.1 GB
# Metric balanced_accuracy is not supported by this model - using log_loss instead
# 	Stopping at the best epoch learned earlier - 2.
# 	2.71s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_BAG_L1/f2de5d78_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.2/21.2 GB
# Metric balanced_accuracy is not supported by this model - using log_loss instead
# 	Stopping at the best epoch learned earlier - 5.
# 	6.54s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_BAG_L1/cb526a97_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.2/21.2 GB
# Metric balanced_accuracy is not supported by this model - using log_loss instead
# 	Stopping at the best epoch learned earlier - 2.
# 	2.91s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_BAG_L1/8f1bdf15_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.2/21.2 GB
# Metric balanced_accuracy is not supported by this model - using log_loss instead
# 	Stopping at the best epoch learned earlier - 6.
# 	7.64s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_BAG_L1/3a852c0a_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.2/21.2 GB
# Metric balanced_accuracy is not supported by this model - using log_loss instead
# 	Stopping at the best epoch learned earlier - 3.
# 	2.83s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_BAG_L1/f49d81a7_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.2/21.2 GB
# Metric balanced_accuracy is not supported by this model - using log_loss instead
# 	Stopping at the best epoch learned earlier - 3.
# 	4.73s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_BAG_L1/6f572e03_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.2/21.2 GB
# Metric balanced_accuracy is not supported by this model - using log_loss instead
# 	Stopping at the best epoch learned earlier - 2.
# 	2.54s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_BAG_L1/T1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=12, gpus=0
# 	11.81s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_BAG_L1/T2_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=12, gpus=0
# 	6.52s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_BAG_L1/T3_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=12, gpus=0, mem=1.1/21.2 GB
# 	20.13s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_BAG_L1/T4_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=12, gpus=0
# 	4.79s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_BAG_L1/T5_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=12, gpus=0, mem=2.0/21.2 GB
# 	10.64s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_BAG_L1/T6_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=12, gpus=0
# 	3.01s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_BAG_L1/T7_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=12, gpus=0, mem=1.1/21.1 GB
# 	16.85s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_BAG_L1/T8_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=12, gpus=0
# 	5.6s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_BAG_L1/T9_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=12, gpus=0
# 	3.34s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_BAG_L1/61e10f1f_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.1/21.2 GB
# 	4.51s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_BAG_L1/3f7e583d_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.1/21.2 GB
# 	74.31s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_BAG_L1/35f2f9bb_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.1/21.1 GB
# 	6.25s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_BAG_L1/27f64188_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.1/21.2 GB
# 	2.17s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_BAG_L1/4b0b353f_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.1/21.2 GB
# 	5.17s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_BAG_L1/0de333c1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.1/21.1 GB
# 	11.1s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_BAG_L1/34528cfb_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.1/21.1 GB
# 	15.64s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_BAG_L1/a08c6a8d_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.1/21.1 GB
# 	5.92s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_BAG_L1/6f1d2692_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.1/21.1 GB
# 	3.47s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_BAG_L1/a3bdf838_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.1/21.1 GB
# 	8.05s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_BAG_L1/8a6e7925_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.1/21.2 GB
# 	6.71s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_BAG_L1/6bb37649_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.1/21.2 GB
# 	11.11s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_BAG_L1/2fed4639_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=10, gpus=0, mem=0.1/21.2 GB
# 	3.5s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBMLarge_BAG_L1_FULL ...
# 	Fitting 1 model on all data | Fitting with cpus=12, gpus=0, mem=0.6/21.2 GB
# 	14.15s	 = Training   runtime
# Fitting model: WeightedEnsemble_L2_FULL | Skipping fit via cloning parent ...
# 	Ensemble Weights: {'XGBoost_BAG_L1/T2': 1.0}
# 	0.1s	 = Training   runtime
# Updated best model to "XGBoost_BAG_L1/T2_FULL" (Previously "WeightedEnsemble_L2"). AutoGluon will default to using "XGBoost_BAG_L1/T2_FULL" for predict() and predict_proba().
# Refit complete, total runtime = 476.86s ... Best model: "XGBoost_BAG_L1/T2_FULL"
# Enabling decision threshold calibration (calibrate_decision_threshold='auto', metric is valid, problem_type is 'binary')
# Calibrating decision threshold to optimize metric balanced_accuracy | Checking 51 thresholds...
# Calibrating decision threshold via fine-grained search | Checking 38 thresholds...
# 	Base Threshold: 0.500	| val: 0.5581
# 	Best Threshold: 0.500	| val: 0.5581
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("/home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1")

# %%
lb = predictor.leaderboard(silent=True)
lb
# Out:
#                               model  score_val        eval_metric  \
# 0                 XGBoost_BAG_L1/T2   0.558067  balanced_accuracy
# 1               WeightedEnsemble_L2   0.558067  balanced_accuracy
# 2    NeuralNetTorch_BAG_L1/0de333c1   0.557884  balanced_accuracy
# 3                 XGBoost_BAG_L1/T4   0.556623  balanced_accuracy
# 4    NeuralNetTorch_BAG_L1/6bb37649   0.555477  balanced_accuracy
# ..                              ...        ...                ...
# 173      LightGBMXT_BAG_L1/T10_FULL        NaN  balanced_accuracy
# 174       LightGBMLarge_BAG_L1_FULL        NaN  balanced_accuracy
# 175         CatBoost_BAG_L1/T3_FULL        NaN  balanced_accuracy
# 176         CatBoost_BAG_L1/T2_FULL        NaN  balanced_accuracy
# 177         CatBoost_BAG_L1/T1_FULL        NaN  balanced_accuracy
#
#      pred_time_val   fit_time  pred_time_val_marginal  fit_time_marginal  \
# 0         0.173583  72.707236                0.173583          72.707236
# 1         0.174298  72.803975                0.000715           0.096740
# 2         0.132553  58.573261                0.132553          58.573261
# 3         0.179575  42.524199                0.179575          42.524199
# 4         0.884679  83.666442                0.884679          83.666442
# ..             ...        ...                     ...                ...
# 173            NaN   3.474485                     NaN           3.474485
# 174            NaN  14.147013                     NaN          14.147013
# 175            NaN  28.464873                     NaN          28.464873
# 176            NaN   1.886889                     NaN           1.886889
# 177            NaN   4.979234                     NaN           4.979234
#
#      stack_level  can_infer  fit_order
# 0              1      False         67
# 1              2      False         89
# 2              1      False         80
# 3              1      False         69
# 4              1      False         86
# ..           ...        ...        ...
# 173            1       True         99
# 174            1       True        177
# 175            1       True        124
# 176            1       True        123
# 177            1       True        122
#
# [178 rows x 10 columns]

# %%
# Keep only the best model (+ its dependencies), delete the rest from disk
predictor.delete_models(models_to_keep="best", delete_from_disk=True)

# (Optional) shrink further by removing auxiliary artifacts not needed for prediction
predictor.save_space(remove_data=True)

# Save back to disk (same folder); after this, the directory is much smaller
predictor.save()
# Out:
# Deleting model LightGBMXT_BAG_L1/T1. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/LightGBMXT_BAG_L1/T1 will be removed.
# Deleting model LightGBMXT_BAG_L1/T2. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/LightGBMXT_BAG_L1/T2 will be removed.
# Deleting model LightGBMXT_BAG_L1/T3. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/LightGBMXT_BAG_L1/T3 will be removed.
# Deleting model LightGBMXT_BAG_L1/T4. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/LightGBMXT_BAG_L1/T4 will be removed.
# Deleting model LightGBMXT_BAG_L1/T5. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/LightGBMXT_BAG_L1/T5 will be removed.
# Deleting model LightGBMXT_BAG_L1/T6. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/LightGBMXT_BAG_L1/T6 will be removed.
# Deleting model LightGBMXT_BAG_L1/T7. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/LightGBMXT_BAG_L1/T7 will be removed.
# Deleting model LightGBMXT_BAG_L1/T8. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/LightGBMXT_BAG_L1/T8 will be removed.
# Deleting model LightGBMXT_BAG_L1/T9. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/LightGBMXT_BAG_L1/T9 will be removed.
# Deleting model LightGBMXT_BAG_L1/T10. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/LightGBMXT_BAG_L1/T10 will be removed.
# Deleting model LightGBMXT_BAG_L1/T11. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/LightGBMXT_BAG_L1/T11 will be removed.
# Deleting model LightGBMXT_BAG_L1/T12. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/LightGBMXT_BAG_L1/T12 will be removed.
# Deleting model LightGBMXT_BAG_L1/T13. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/LightGBMXT_BAG_L1/T13 will be removed.
# Deleting model LightGBMXT_BAG_L1/T14. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/LightGBMXT_BAG_L1/T14 will be removed.
# Deleting model LightGBMXT_BAG_L1/T15. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/LightGBMXT_BAG_L1/T15 will be removed.
# Deleting model LightGBMXT_BAG_L1/T16. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/LightGBMXT_BAG_L1/T16 will be removed.
# Deleting model LightGBMXT_BAG_L1/T17. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/LightGBMXT_BAG_L1/T17 will be removed.
# Deleting model LightGBMXT_BAG_L1/T18. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/LightGBMXT_BAG_L1/T18 will be removed.
# Deleting model LightGBMXT_BAG_L1/T19. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/LightGBMXT_BAG_L1/T19 will be removed.
# Deleting model LightGBMXT_BAG_L1/T20. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/LightGBMXT_BAG_L1/T20 will be removed.
# Deleting model LightGBMXT_BAG_L1/T21. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/LightGBMXT_BAG_L1/T21 will be removed.
# Deleting model LightGBM_BAG_L1/T1. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/LightGBM_BAG_L1/T1 will be removed.
# Deleting model LightGBM_BAG_L1/T2. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/LightGBM_BAG_L1/T2 will be removed.
# Deleting model LightGBM_BAG_L1/T3. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/LightGBM_BAG_L1/T3 will be removed.
# Deleting model LightGBM_BAG_L1/T4. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/LightGBM_BAG_L1/T4 will be removed.
# Deleting model LightGBM_BAG_L1/T5. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/LightGBM_BAG_L1/T5 will be removed.
# Deleting model LightGBM_BAG_L1/T6. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/LightGBM_BAG_L1/T6 will be removed.
# Deleting model LightGBM_BAG_L1/T7. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/LightGBM_BAG_L1/T7 will be removed.
# Deleting model LightGBM_BAG_L1/T8. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/LightGBM_BAG_L1/T8 will be removed.
# Deleting model LightGBM_BAG_L1/T9. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/LightGBM_BAG_L1/T9 will be removed.
# Deleting model RandomForestGini_BAG_L1. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/RandomForestGini_BAG_L1 will be removed.
# Deleting model RandomForestEntr_BAG_L1. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/RandomForestEntr_BAG_L1 will be removed.
# Deleting model CatBoost_BAG_L1/T1. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/CatBoost_BAG_L1/T1 will be removed.
# Deleting model CatBoost_BAG_L1/T2. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/CatBoost_BAG_L1/T2 will be removed.
# Deleting model CatBoost_BAG_L1/T3. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/CatBoost_BAG_L1/T3 will be removed.
# Deleting model ExtraTreesGini_BAG_L1. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/ExtraTreesGini_BAG_L1 will be removed.
# Deleting model ExtraTreesEntr_BAG_L1. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/ExtraTreesEntr_BAG_L1 will be removed.
# Deleting model NeuralNetFastAI_BAG_L1/bd81d8e4. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L1/bd81d8e4 will be removed.
# Deleting model NeuralNetFastAI_BAG_L1/2b7edef2. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L1/2b7edef2 will be removed.
# Deleting model NeuralNetFastAI_BAG_L1/ecd71730. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L1/ecd71730 will be removed.
# Deleting model NeuralNetFastAI_BAG_L1/dffc69e3. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L1/dffc69e3 will be removed.
# Deleting model NeuralNetFastAI_BAG_L1/f37d82ee. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L1/f37d82ee will be removed.
# Deleting model NeuralNetFastAI_BAG_L1/06cccef4. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L1/06cccef4 will be removed.
# Deleting model NeuralNetFastAI_BAG_L1/5a40119d. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L1/5a40119d will be removed.
# Deleting model NeuralNetFastAI_BAG_L1/6963845e. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L1/6963845e will be removed.
# Deleting model NeuralNetFastAI_BAG_L1/7d4cff15. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L1/7d4cff15 will be removed.
# Deleting model NeuralNetFastAI_BAG_L1/fe2bff87. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L1/fe2bff87 will be removed.
# Deleting model NeuralNetFastAI_BAG_L1/f0e99916. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L1/f0e99916 will be removed.
# Deleting model NeuralNetFastAI_BAG_L1/fcfe898d. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L1/fcfe898d will be removed.
# Deleting model NeuralNetFastAI_BAG_L1/a0ee84c2. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L1/a0ee84c2 will be removed.
# Deleting model NeuralNetFastAI_BAG_L1/5be9439d. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L1/5be9439d will be removed.
# Deleting model NeuralNetFastAI_BAG_L1/e92ab7ec. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L1/e92ab7ec will be removed.
# Deleting model NeuralNetFastAI_BAG_L1/062d6a1a. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L1/062d6a1a will be removed.
# Deleting model NeuralNetFastAI_BAG_L1/10089b41. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L1/10089b41 will be removed.
# Deleting model NeuralNetFastAI_BAG_L1/07ff95e4. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L1/07ff95e4 will be removed.
# Deleting model NeuralNetFastAI_BAG_L1/369f8116. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L1/369f8116 will be removed.
# Deleting model NeuralNetFastAI_BAG_L1/6826ae72. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L1/6826ae72 will be removed.
# Deleting model NeuralNetFastAI_BAG_L1/124d7b3b. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L1/124d7b3b will be removed.
# Deleting model NeuralNetFastAI_BAG_L1/40debbcc. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L1/40debbcc will be removed.
# Deleting model NeuralNetFastAI_BAG_L1/f2de5d78. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L1/f2de5d78 will be removed.
# Deleting model NeuralNetFastAI_BAG_L1/cb526a97. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L1/cb526a97 will be removed.
# Deleting model NeuralNetFastAI_BAG_L1/8f1bdf15. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L1/8f1bdf15 will be removed.
# Deleting model NeuralNetFastAI_BAG_L1/3a852c0a. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L1/3a852c0a will be removed.
# Deleting model NeuralNetFastAI_BAG_L1/f49d81a7. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L1/f49d81a7 will be removed.
# Deleting model NeuralNetFastAI_BAG_L1/6f572e03. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L1/6f572e03 will be removed.
# Deleting model XGBoost_BAG_L1/T1. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/XGBoost_BAG_L1/T1 will be removed.
# Deleting model XGBoost_BAG_L1/T2. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/XGBoost_BAG_L1/T2 will be removed.
# Deleting model XGBoost_BAG_L1/T3. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/XGBoost_BAG_L1/T3 will be removed.
# Deleting model XGBoost_BAG_L1/T4. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/XGBoost_BAG_L1/T4 will be removed.
# Deleting model XGBoost_BAG_L1/T5. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/XGBoost_BAG_L1/T5 will be removed.
# Deleting model XGBoost_BAG_L1/T6. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/XGBoost_BAG_L1/T6 will be removed.
# Deleting model XGBoost_BAG_L1/T7. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/XGBoost_BAG_L1/T7 will be removed.
# Deleting model XGBoost_BAG_L1/T8. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/XGBoost_BAG_L1/T8 will be removed.
# Deleting model XGBoost_BAG_L1/T9. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/XGBoost_BAG_L1/T9 will be removed.
# Deleting model NeuralNetTorch_BAG_L1/61e10f1f. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetTorch_BAG_L1/61e10f1f will be removed.
# Deleting model NeuralNetTorch_BAG_L1/3f7e583d. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetTorch_BAG_L1/3f7e583d will be removed.
# Deleting model NeuralNetTorch_BAG_L1/35f2f9bb. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetTorch_BAG_L1/35f2f9bb will be removed.
# Deleting model NeuralNetTorch_BAG_L1/27f64188. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetTorch_BAG_L1/27f64188 will be removed.
# Deleting model NeuralNetTorch_BAG_L1/4b0b353f. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetTorch_BAG_L1/4b0b353f will be removed.
# Deleting model NeuralNetTorch_BAG_L1/0de333c1. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetTorch_BAG_L1/0de333c1 will be removed.
# Deleting model NeuralNetTorch_BAG_L1/34528cfb. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetTorch_BAG_L1/34528cfb will be removed.
# Deleting model NeuralNetTorch_BAG_L1/a08c6a8d. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetTorch_BAG_L1/a08c6a8d will be removed.
# Deleting model NeuralNetTorch_BAG_L1/6f1d2692. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetTorch_BAG_L1/6f1d2692 will be removed.
# Deleting model NeuralNetTorch_BAG_L1/a3bdf838. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetTorch_BAG_L1/a3bdf838 will be removed.
# Deleting model NeuralNetTorch_BAG_L1/8a6e7925. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetTorch_BAG_L1/8a6e7925 will be removed.
# Deleting model NeuralNetTorch_BAG_L1/6bb37649. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetTorch_BAG_L1/6bb37649 will be removed.
# Deleting model NeuralNetTorch_BAG_L1/2fed4639. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetTorch_BAG_L1/2fed4639 will be removed.
# Deleting model LightGBMLarge_BAG_L1. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/LightGBMLarge_BAG_L1 will be removed.
# Deleting model WeightedEnsemble_L2. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/WeightedEnsemble_L2 will be removed.
# Deleting model LightGBMXT_BAG_L1/T1_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/LightGBMXT_BAG_L1/T1_FULL will be removed.
# Deleting model LightGBMXT_BAG_L1/T2_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/LightGBMXT_BAG_L1/T2_FULL will be removed.
# Deleting model LightGBMXT_BAG_L1/T3_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/LightGBMXT_BAG_L1/T3_FULL will be removed.
# Deleting model LightGBMXT_BAG_L1/T4_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/LightGBMXT_BAG_L1/T4_FULL will be removed.
# Deleting model LightGBMXT_BAG_L1/T5_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/LightGBMXT_BAG_L1/T5_FULL will be removed.
# Deleting model LightGBMXT_BAG_L1/T6_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/LightGBMXT_BAG_L1/T6_FULL will be removed.
# Deleting model LightGBMXT_BAG_L1/T7_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/LightGBMXT_BAG_L1/T7_FULL will be removed.
# Deleting model LightGBMXT_BAG_L1/T8_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/LightGBMXT_BAG_L1/T8_FULL will be removed.
# Deleting model LightGBMXT_BAG_L1/T9_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/LightGBMXT_BAG_L1/T9_FULL will be removed.
# Deleting model LightGBMXT_BAG_L1/T10_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/LightGBMXT_BAG_L1/T10_FULL will be removed.
# Deleting model LightGBMXT_BAG_L1/T11_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/LightGBMXT_BAG_L1/T11_FULL will be removed.
# Deleting model LightGBMXT_BAG_L1/T12_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/LightGBMXT_BAG_L1/T12_FULL will be removed.
# Deleting model LightGBMXT_BAG_L1/T13_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/LightGBMXT_BAG_L1/T13_FULL will be removed.
# Deleting model LightGBMXT_BAG_L1/T14_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/LightGBMXT_BAG_L1/T14_FULL will be removed.
# Deleting model LightGBMXT_BAG_L1/T15_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/LightGBMXT_BAG_L1/T15_FULL will be removed.
# Deleting model LightGBMXT_BAG_L1/T16_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/LightGBMXT_BAG_L1/T16_FULL will be removed.
# Deleting model LightGBMXT_BAG_L1/T17_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/LightGBMXT_BAG_L1/T17_FULL will be removed.
# Deleting model LightGBMXT_BAG_L1/T18_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/LightGBMXT_BAG_L1/T18_FULL will be removed.
# Deleting model LightGBMXT_BAG_L1/T19_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/LightGBMXT_BAG_L1/T19_FULL will be removed.
# Deleting model LightGBMXT_BAG_L1/T20_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/LightGBMXT_BAG_L1/T20_FULL will be removed.
# Deleting model LightGBMXT_BAG_L1/T21_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/LightGBMXT_BAG_L1/T21_FULL will be removed.
# Deleting model LightGBM_BAG_L1/T1_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/LightGBM_BAG_L1/T1_FULL will be removed.
# Deleting model LightGBM_BAG_L1/T2_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/LightGBM_BAG_L1/T2_FULL will be removed.
# Deleting model LightGBM_BAG_L1/T3_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/LightGBM_BAG_L1/T3_FULL will be removed.
# Deleting model LightGBM_BAG_L1/T4_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/LightGBM_BAG_L1/T4_FULL will be removed.
# Deleting model LightGBM_BAG_L1/T5_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/LightGBM_BAG_L1/T5_FULL will be removed.
# Deleting model LightGBM_BAG_L1/T6_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/LightGBM_BAG_L1/T6_FULL will be removed.
# Deleting model LightGBM_BAG_L1/T7_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/LightGBM_BAG_L1/T7_FULL will be removed.
# Deleting model LightGBM_BAG_L1/T8_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/LightGBM_BAG_L1/T8_FULL will be removed.
# Deleting model LightGBM_BAG_L1/T9_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/LightGBM_BAG_L1/T9_FULL will be removed.
# Deleting model RandomForestGini_BAG_L1_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/RandomForestGini_BAG_L1_FULL will be removed.
# Deleting model RandomForestEntr_BAG_L1_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/RandomForestEntr_BAG_L1_FULL will be removed.
# Deleting model CatBoost_BAG_L1/T1_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/CatBoost_BAG_L1/T1_FULL will be removed.
# Deleting model CatBoost_BAG_L1/T2_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/CatBoost_BAG_L1/T2_FULL will be removed.
# Deleting model CatBoost_BAG_L1/T3_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/CatBoost_BAG_L1/T3_FULL will be removed.
# Deleting model ExtraTreesGini_BAG_L1_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/ExtraTreesGini_BAG_L1_FULL will be removed.
# Deleting model ExtraTreesEntr_BAG_L1_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/ExtraTreesEntr_BAG_L1_FULL will be removed.
# Deleting model NeuralNetFastAI_BAG_L1/bd81d8e4_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L1/bd81d8e4_FULL will be removed.
# Deleting model NeuralNetFastAI_BAG_L1/2b7edef2_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L1/2b7edef2_FULL will be removed.
# Deleting model NeuralNetFastAI_BAG_L1/ecd71730_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L1/ecd71730_FULL will be removed.
# Deleting model NeuralNetFastAI_BAG_L1/dffc69e3_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L1/dffc69e3_FULL will be removed.
# Deleting model NeuralNetFastAI_BAG_L1/f37d82ee_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L1/f37d82ee_FULL will be removed.
# Deleting model NeuralNetFastAI_BAG_L1/06cccef4_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L1/06cccef4_FULL will be removed.
# Deleting model NeuralNetFastAI_BAG_L1/5a40119d_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L1/5a40119d_FULL will be removed.
# Deleting model NeuralNetFastAI_BAG_L1/6963845e_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L1/6963845e_FULL will be removed.
# Deleting model NeuralNetFastAI_BAG_L1/7d4cff15_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L1/7d4cff15_FULL will be removed.
# Deleting model NeuralNetFastAI_BAG_L1/fe2bff87_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L1/fe2bff87_FULL will be removed.
# Deleting model NeuralNetFastAI_BAG_L1/f0e99916_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L1/f0e99916_FULL will be removed.
# Deleting model NeuralNetFastAI_BAG_L1/fcfe898d_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L1/fcfe898d_FULL will be removed.
# Deleting model NeuralNetFastAI_BAG_L1/a0ee84c2_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L1/a0ee84c2_FULL will be removed.
# Deleting model NeuralNetFastAI_BAG_L1/5be9439d_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L1/5be9439d_FULL will be removed.
# Deleting model NeuralNetFastAI_BAG_L1/e92ab7ec_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L1/e92ab7ec_FULL will be removed.
# Deleting model NeuralNetFastAI_BAG_L1/062d6a1a_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L1/062d6a1a_FULL will be removed.
# Deleting model NeuralNetFastAI_BAG_L1/10089b41_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L1/10089b41_FULL will be removed.
# Deleting model NeuralNetFastAI_BAG_L1/07ff95e4_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L1/07ff95e4_FULL will be removed.
# Deleting model NeuralNetFastAI_BAG_L1/369f8116_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L1/369f8116_FULL will be removed.
# Deleting model NeuralNetFastAI_BAG_L1/6826ae72_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L1/6826ae72_FULL will be removed.
# Deleting model NeuralNetFastAI_BAG_L1/124d7b3b_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L1/124d7b3b_FULL will be removed.
# Deleting model NeuralNetFastAI_BAG_L1/40debbcc_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L1/40debbcc_FULL will be removed.
# Deleting model NeuralNetFastAI_BAG_L1/f2de5d78_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L1/f2de5d78_FULL will be removed.
# Deleting model NeuralNetFastAI_BAG_L1/cb526a97_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L1/cb526a97_FULL will be removed.
# Deleting model NeuralNetFastAI_BAG_L1/8f1bdf15_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L1/8f1bdf15_FULL will be removed.
# Deleting model NeuralNetFastAI_BAG_L1/3a852c0a_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L1/3a852c0a_FULL will be removed.
# Deleting model NeuralNetFastAI_BAG_L1/f49d81a7_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L1/f49d81a7_FULL will be removed.
# Deleting model NeuralNetFastAI_BAG_L1/6f572e03_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetFastAI_BAG_L1/6f572e03_FULL will be removed.
# Deleting model XGBoost_BAG_L1/T1_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/XGBoost_BAG_L1/T1_FULL will be removed.
# Deleting model XGBoost_BAG_L1/T3_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/XGBoost_BAG_L1/T3_FULL will be removed.
# Deleting model XGBoost_BAG_L1/T4_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/XGBoost_BAG_L1/T4_FULL will be removed.
# Deleting model XGBoost_BAG_L1/T5_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/XGBoost_BAG_L1/T5_FULL will be removed.
# Deleting model XGBoost_BAG_L1/T6_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/XGBoost_BAG_L1/T6_FULL will be removed.
# Deleting model XGBoost_BAG_L1/T7_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/XGBoost_BAG_L1/T7_FULL will be removed.
# Deleting model XGBoost_BAG_L1/T8_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/XGBoost_BAG_L1/T8_FULL will be removed.
# Deleting model XGBoost_BAG_L1/T9_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/XGBoost_BAG_L1/T9_FULL will be removed.
# Deleting model NeuralNetTorch_BAG_L1/61e10f1f_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetTorch_BAG_L1/61e10f1f_FULL will be removed.
# Deleting model NeuralNetTorch_BAG_L1/3f7e583d_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetTorch_BAG_L1/3f7e583d_FULL will be removed.
# Deleting model NeuralNetTorch_BAG_L1/35f2f9bb_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetTorch_BAG_L1/35f2f9bb_FULL will be removed.
# Deleting model NeuralNetTorch_BAG_L1/27f64188_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetTorch_BAG_L1/27f64188_FULL will be removed.
# Deleting model NeuralNetTorch_BAG_L1/4b0b353f_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetTorch_BAG_L1/4b0b353f_FULL will be removed.
# Deleting model NeuralNetTorch_BAG_L1/0de333c1_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetTorch_BAG_L1/0de333c1_FULL will be removed.
# Deleting model NeuralNetTorch_BAG_L1/34528cfb_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetTorch_BAG_L1/34528cfb_FULL will be removed.
# Deleting model NeuralNetTorch_BAG_L1/a08c6a8d_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetTorch_BAG_L1/a08c6a8d_FULL will be removed.
# Deleting model NeuralNetTorch_BAG_L1/6f1d2692_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetTorch_BAG_L1/6f1d2692_FULL will be removed.
# Deleting model NeuralNetTorch_BAG_L1/a3bdf838_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetTorch_BAG_L1/a3bdf838_FULL will be removed.
# Deleting model NeuralNetTorch_BAG_L1/8a6e7925_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetTorch_BAG_L1/8a6e7925_FULL will be removed.
# Deleting model NeuralNetTorch_BAG_L1/6bb37649_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetTorch_BAG_L1/6bb37649_FULL will be removed.
# Deleting model NeuralNetTorch_BAG_L1/2fed4639_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/NeuralNetTorch_BAG_L1/2fed4639_FULL will be removed.
# Deleting model LightGBMLarge_BAG_L1_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/LightGBMLarge_BAG_L1_FULL will be removed.
# Deleting model WeightedEnsemble_L2_FULL. All files under /home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1/models/WeightedEnsemble_L2_FULL will be removed.
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("/home/adrian_alvarez/Projects/NBA_over_under_predictor/models/classifier_autoglue_1")

# %% [markdown]
# ## Test Set Evaluation (Best Model)

# %%
y_test_pred = predictor.predict(X_test)

metrics = {
    "accuracy": accuracy_score(y_test, y_test_pred),
    "balanced_accuracy": balanced_accuracy_score(y_test, y_test_pred),
    "precision": precision_score(y_test, y_test_pred),
    "recall": recall_score(y_test, y_test_pred),
    "f1": f1_score(y_test, y_test_pred),
    "error_rate": 1 - accuracy_score(y_test, y_test_pred),
}

pd.Series(metrics).round(4)
# Out:
# accuracy             0.5213
# balanced_accuracy    0.5182
# precision            0.4908
# recall               0.4651
# f1                   0.4776
# error_rate           0.4787
# dtype: float64
